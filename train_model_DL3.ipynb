# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Dataset
from tqdm import tqdm
import matplotlib.pyplot as plt
import pandas as pd
from DL_Models import DLModels
from logging_config import setup_logger
from tools import save_json, load_json

# %%
# 自定义数据集类，用于处理二维特征输入
class TabularDataset(Dataset):
    def __init__(self, X, Y, transform=None):
        self.X = X.values
        self.Y = Y.values
        self.transform = transform

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        x = self.X[idx]
        y = self.Y[idx]
        # 升维处理，将特征转换为适合卷积模型的输入格式 (C, H, W)
        x = torch.tensor(x, dtype=torch.float32).unsqueeze(1).repeat(3, 1, 1)
        if self.transform:
            x = self.transform(x)
        return x, torch.tensor(y, dtype=torch.float32)

# 转换为适合预训练模型输入的格式
def transform_input(X):
    transform = transforms.Compose([
        transforms.Normalize(mean=[0.5] * 3, std=[0.5] * 3)
    ])
    return transform

# 创建数据集和数据加载器
def create_data_loaders(X, Y, batch_size=1024):
    dataset = TabularDataset(X, Y)
    train_size = int(0.8 * len(dataset))
    test_size = len(dataset) - train_size
    train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    return train_loader, test_loader


# 读取数据
def load_data(file_path):
    df = pd.read_csv(file_path)
    X = df.iloc[:, 1:38]
    Y = df.iloc[:, 38:]
    return X, Y

# %%
# 自定义损失函数，用于处理数据不平衡问题
class CustomBCELoss(nn.Module):
    def __init__(self, pos_weight):
        super(CustomBCELoss, self).__init__()
        self.pos_weight = pos_weight

    def forward(self, outputs, targets):
        outputs, targets = outputs.to(self.pos_weight.device), targets.to(self.pos_weight.device)
        loss = nn.functional.binary_cross_entropy_with_logits(outputs, targets, pos_weight=self.pos_weight)
        return loss

# %%
# 训练过程
def train_epoch(model, train_loader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    for inputs, targets in tqdm(train_loader, desc="Training"):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    train_loss = running_loss / len(train_loader)
    return train_loss

# 验证过程
def validate_epoch(model, test_loader, criterion, device):
    model.eval()
    val_running_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, targets in tqdm(test_loader, desc="Validation"):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            val_loss = criterion(outputs, targets)
            val_running_loss += val_loss.item()
            preds = torch.sigmoid(outputs).round()
            correct += (preds == targets).sum().item()
            total += targets.numel()
    val_loss = val_running_loss / len(test_loader)
    val_accuracy = correct / total
    return val_loss, val_accuracy

# 训练模型并添加CUDA和tqdm可视化
def train_model(model, train_loader, test_loader, criterion, optimizer, logger, model_name, epochs=10):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    criterion = criterion.to(device)

    train_losses = []
    val_losses = []
    val_accuracies = []

    best_val_accuracy = 0.0
    best_model_path = f'DL3_output/{model_name}_best_model_DL3.pth'

    for epoch in range(epochs):
        train_loss = train_epoch(model, train_loader, criterion, optimizer, device)
        val_loss, val_accuracy = validate_epoch(model, test_loader, criterion, device)

        train_losses.append(train_loss)
        val_losses.append(val_loss)
        val_accuracies.append(val_accuracy)

        logger.info(f'Epoch [{epoch+1}/{epochs}], Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, Val Accuracy: {val_accuracy:.4f}')
        
        # 保存最优模型
        if val_accuracy > best_val_accuracy:
            best_val_accuracy = val_accuracy
            torch.save(model.state_dict(), best_model_path)
            logger.info(f'Best model saved with accuracy: {best_val_accuracy:.4f}')
    return  train_losses, val_losses, val_accuracies

# %%
# 读取数据
X, Y = load_data('trin_df.csv')  # 请替换为你的数据集路径
epochs = 800
# 创建数据加载器
batch_size = 1024
train_loader, test_loader = create_data_loaders(X, Y, batch_size)

# 定义模型
output_dim = Y.shape[1]
models = {'resnet18':DLModels.resnet18(output_dim),
          'resnet50':DLModels.resnet50(output_dim),
        #   'vgg16':DLModels.vgg16(output_dim),
        #   'densenet121':DLModels.densenet121(output_dim),
        #  'mobilenet_v2':DLModels.mobilenet_v2(output_dim)
        }

logger = setup_logger(rf'DL3_output/DL3.log')

for model_name in list(models.keys()):
    results = {}
    model = models[model_name]

    # 损失函数和优化器
    # 计算每列中正样本的权重，用于平衡损失函数中的正负样本
    pos_weight = torch.tensor((Y.shape[0] - Y.sum()) / Y.sum(), dtype=torch.float32)
    criterion = CustomBCELoss(pos_weight=pos_weight)
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    # 训练模型
    train_losses, val_losses, val_accuracies = train_model(model, train_loader, test_loader, criterion, optimizer, logger,model_name, epochs)

    results[model_name] = (train_losses, val_losses, val_accuracies)

    save_json(results,rf'DL3_output/DL3_{model_name}_results.json')
# Out:
# C:\Users\PGR\AppData\Local\Temp\ipykernel_19140\1354343950.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pos_weight = torch.tensor((Y.shape[0] - Y.sum()) / Y.sum(), dtype=torch.float32)
# Training: 100%|██████████| 189/189 [02:00<00:00,  1.57it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.44it/s]
# 2024-10-31 21:46:40,369 - logging_config - INFO - Epoch [1/800], Train Loss: 1.3871, Val Loss: 1.3905, Val Accuracy: 0.5873
# 2024-10-31 21:46:40,630 - logging_config - INFO - Best model saved with accuracy: 0.5873
# Training: 100%|██████████| 189/189 [01:51<00:00,  1.70it/s]
# Validation: 100%|██████████| 48/48 [00:21<00:00,  2.19it/s]
# 2024-10-31 21:48:53,708 - logging_config - INFO - Epoch [2/800], Train Loss: 1.4011, Val Loss: 1.3881, Val Accuracy: 0.6323
# 2024-10-31 21:48:54,020 - logging_config - INFO - Best model saved with accuracy: 0.6323
# Training: 100%|██████████| 189/189 [01:54<00:00,  1.65it/s]
# Validation: 100%|██████████| 48/48 [00:20<00:00,  2.40it/s]
# 2024-10-31 21:51:08,752 - logging_config - INFO - Epoch [3/800], Train Loss: 1.3701, Val Loss: 1.3944, Val Accuracy: 0.6343
# 2024-10-31 21:51:09,025 - logging_config - INFO - Best model saved with accuracy: 0.6343
# Training: 100%|██████████| 189/189 [01:48<00:00,  1.74it/s]
# Validation: 100%|██████████| 48/48 [00:21<00:00,  2.21it/s]
# 2024-10-31 21:53:19,617 - logging_config - INFO - Epoch [4/800], Train Loss: 1.3699, Val Loss: 1.3793, Val Accuracy: 0.5998
# Training: 100%|██████████| 189/189 [02:00<00:00,  1.57it/s]
# Validation: 100%|██████████| 48/48 [00:22<00:00,  2.18it/s]
# 2024-10-31 21:55:42,060 - logging_config - INFO - Epoch [5/800], Train Loss: 1.3788, Val Loss: 1.3837, Val Accuracy: 0.4351
# Training: 100%|██████████| 189/189 [01:59<00:00,  1.59it/s]
# Validation: 100%|██████████| 48/48 [00:22<00:00,  2.16it/s]
# 2024-10-31 21:58:03,375 - logging_config - INFO - Epoch [6/800], Train Loss: 1.3565, Val Loss: 1.4496, Val Accuracy: 0.5034
# Training: 100%|██████████| 189/189 [02:01<00:00,  1.55it/s]
# Validation: 100%|██████████| 48/48 [00:22<00:00,  2.17it/s]
# 2024-10-31 22:00:27,171 - logging_config - INFO - Epoch [7/800], Train Loss: 1.3514, Val Loss: 1.4399, Val Accuracy: 0.4072
# Training: 100%|██████████| 189/189 [01:49<00:00,  1.72it/s]
# Validation: 100%|██████████| 48/48 [00:20<00:00,  2.37it/s]
# 2024-10-31 22:02:37,311 - logging_config - INFO - Epoch [8/800], Train Loss: 1.3525, Val Loss: 1.4327, Val Accuracy: 0.4449
# Training: 100%|██████████| 189/189 [01:46<00:00,  1.77it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.57it/s]
# 2024-10-31 22:04:42,459 - logging_config - INFO - Epoch [9/800], Train Loss: 1.3684, Val Loss: 1.4632, Val Accuracy: 0.6489
# 2024-10-31 22:04:42,707 - logging_config - INFO - Best model saved with accuracy: 0.6489
# Training: 100%|██████████| 189/189 [01:47<00:00,  1.76it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.54it/s]
# 2024-10-31 22:06:49,174 - logging_config - INFO - Epoch [10/800], Train Loss: 1.3579, Val Loss: 1.4654, Val Accuracy: 0.4451
# Training: 100%|██████████| 189/189 [01:46<00:00,  1.78it/s]
# Validation: 100%|██████████| 48/48 [00:20<00:00,  2.33it/s]
# 2024-10-31 22:08:56,017 - logging_config - INFO - Epoch [11/800], Train Loss: 1.3498, Val Loss: 1.4728, Val Accuracy: 0.5767
# Training: 100%|██████████| 189/189 [01:48<00:00,  1.74it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.51it/s]
# 2024-10-31 22:11:03,704 - logging_config - INFO - Epoch [12/800], Train Loss: 1.3531, Val Loss: 1.4911, Val Accuracy: 0.4297
# Training: 100%|██████████| 189/189 [01:47<00:00,  1.76it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.52it/s]
# 2024-10-31 22:13:10,120 - logging_config - INFO - Epoch [13/800], Train Loss: 1.3477, Val Loss: 1.5254, Val Accuracy: 0.4655
# Training: 100%|██████████| 189/189 [01:46<00:00,  1.78it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.53it/s]
# 2024-10-31 22:15:15,591 - logging_config - INFO - Epoch [14/800], Train Loss: 1.3446, Val Loss: 1.5520, Val Accuracy: 0.4818
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.79it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.54it/s]
# 2024-10-31 22:17:20,119 - logging_config - INFO - Epoch [15/800], Train Loss: 1.3438, Val Loss: 1.4427, Val Accuracy: 0.5350
# Training: 100%|██████████| 189/189 [01:46<00:00,  1.78it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.52it/s]
# 2024-10-31 22:19:25,461 - logging_config - INFO - Epoch [16/800], Train Loss: 1.3472, Val Loss: 1.5180, Val Accuracy: 0.5320
# Training: 100%|██████████| 189/189 [01:46<00:00,  1.77it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.46it/s]
# 2024-10-31 22:21:31,532 - logging_config - INFO - Epoch [17/800], Train Loss: 1.3471, Val Loss: 1.5536, Val Accuracy: 0.4799
# Training: 100%|██████████| 189/189 [01:48<00:00,  1.74it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.54it/s]
# 2024-10-31 22:23:39,261 - logging_config - INFO - Epoch [18/800], Train Loss: 1.3470, Val Loss: 1.5285, Val Accuracy: 0.5452
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.80it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.54it/s]
# 2024-10-31 22:25:43,273 - logging_config - INFO - Epoch [19/800], Train Loss: 1.3423, Val Loss: 1.4763, Val Accuracy: 0.5287
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.80it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.54it/s]
# 2024-10-31 22:27:47,064 - logging_config - INFO - Epoch [20/800], Train Loss: 1.3383, Val Loss: 1.5633, Val Accuracy: 0.6118
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.80it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.54it/s]
# 2024-10-31 22:29:50,913 - logging_config - INFO - Epoch [21/800], Train Loss: 1.3381, Val Loss: 1.5826, Val Accuracy: 0.5448
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.80it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.55it/s]
# 2024-10-31 22:31:54,659 - logging_config - INFO - Epoch [22/800], Train Loss: 1.3332, Val Loss: 1.5264, Val Accuracy: 0.5525
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.80it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.54it/s]
# 2024-10-31 22:33:58,355 - logging_config - INFO - Epoch [23/800], Train Loss: 1.3370, Val Loss: 1.5047, Val Accuracy: 0.5260
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.80it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.56it/s]
# 2024-10-31 22:36:01,985 - logging_config - INFO - Epoch [24/800], Train Loss: 1.3354, Val Loss: 1.4920, Val Accuracy: 0.4835
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.80it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.54it/s]
# 2024-10-31 22:38:05,582 - logging_config - INFO - Epoch [25/800], Train Loss: 1.3340, Val Loss: 1.4651, Val Accuracy: 0.5264
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.80it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.56it/s]
# 2024-10-31 22:40:09,310 - logging_config - INFO - Epoch [26/800], Train Loss: 1.3984, Val Loss: 1.6282, Val Accuracy: 0.7276
# 2024-10-31 22:40:09,622 - logging_config - INFO - Best model saved with accuracy: 0.7276
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.79it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.47it/s]
# 2024-10-31 22:42:14,438 - logging_config - INFO - Epoch [27/800], Train Loss: 1.4170, Val Loss: 1.5049, Val Accuracy: 0.6093
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.78it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.51it/s]
# 2024-10-31 22:44:19,550 - logging_config - INFO - Epoch [28/800], Train Loss: 1.3824, Val Loss: 1.3718, Val Accuracy: 0.3242
# Training: 100%|██████████| 189/189 [01:51<00:00,  1.69it/s]
# Validation: 100%|██████████| 48/48 [00:21<00:00,  2.27it/s]
# 2024-10-31 22:46:32,471 - logging_config - INFO - Epoch [29/800], Train Loss: 1.3484, Val Loss: 1.3547, Val Accuracy: 0.4171
# Training: 100%|██████████| 189/189 [01:50<00:00,  1.71it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.43it/s]
# 2024-10-31 22:48:42,921 - logging_config - INFO - Epoch [30/800], Train Loss: 1.3447, Val Loss: 1.4868, Val Accuracy: 0.3984
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.78it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.44it/s]
# 2024-10-31 22:50:48,562 - logging_config - INFO - Epoch [31/800], Train Loss: 1.3508, Val Loss: 1.4317, Val Accuracy: 0.6601
# Training: 100%|██████████| 189/189 [01:48<00:00,  1.75it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.46it/s]
# 2024-10-31 22:52:56,326 - logging_config - INFO - Epoch [32/800], Train Loss: 1.3407, Val Loss: 1.4007, Val Accuracy: 0.5733
# Training: 100%|██████████| 189/189 [01:57<00:00,  1.61it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.54it/s]
# 2024-10-31 22:55:12,464 - logging_config - INFO - Epoch [33/800], Train Loss: 1.3465, Val Loss: 1.4894, Val Accuracy: 0.5276
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.79it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.54it/s]
# 2024-10-31 22:57:17,174 - logging_config - INFO - Epoch [34/800], Train Loss: 1.3479, Val Loss: 1.3610, Val Accuracy: 0.4302
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.78it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.53it/s]
# 2024-10-31 22:59:22,103 - logging_config - INFO - Epoch [35/800], Train Loss: 1.3378, Val Loss: 1.6371, Val Accuracy: 0.5339
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.81it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.56it/s]
# 2024-10-31 23:01:25,332 - logging_config - INFO - Epoch [36/800], Train Loss: 1.3451, Val Loss: 1.4940, Val Accuracy: 0.5139
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.81it/s]
# Validation: 100%|██████████| 48/48 [00:20<00:00,  2.37it/s]
# 2024-10-31 23:03:30,139 - logging_config - INFO - Epoch [37/800], Train Loss: 1.3395, Val Loss: 1.4305, Val Accuracy: 0.4832
# Training: 100%|██████████| 189/189 [01:47<00:00,  1.76it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.49it/s]
# 2024-10-31 23:05:37,023 - logging_config - INFO - Epoch [38/800], Train Loss: 1.3380, Val Loss: 1.4279, Val Accuracy: 0.4964
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.81it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.42it/s]
# 2024-10-31 23:07:41,457 - logging_config - INFO - Epoch [39/800], Train Loss: 1.3357, Val Loss: 1.5449, Val Accuracy: 0.4926
# Training: 100%|██████████| 189/189 [01:50<00:00,  1.71it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.42it/s]
# 2024-10-31 23:09:51,846 - logging_config - INFO - Epoch [40/800], Train Loss: 1.3423, Val Loss: 1.4990, Val Accuracy: 0.5693
# Training: 100%|██████████| 189/189 [01:53<00:00,  1.66it/s]
# Validation: 100%|██████████| 48/48 [00:20<00:00,  2.35it/s]
# 2024-10-31 23:12:05,911 - logging_config - INFO - Epoch [41/800], Train Loss: 1.3595, Val Loss: 1.4788, Val Accuracy: 0.4199
# Training: 100%|██████████| 189/189 [01:49<00:00,  1.73it/s]
# Validation: 100%|██████████| 48/48 [00:20<00:00,  2.35it/s]
# 2024-10-31 23:14:15,835 - logging_config - INFO - Epoch [42/800], Train Loss: 1.3708, Val Loss: 1.6673, Val Accuracy: 0.6715
# Training: 100%|██████████| 189/189 [01:50<00:00,  1.70it/s]
# Validation: 100%|██████████| 48/48 [00:22<00:00,  2.16it/s]
# 2024-10-31 23:16:29,014 - logging_config - INFO - Epoch [43/800], Train Loss: 1.3788, Val Loss: 1.5102, Val Accuracy: 0.7098
# Training: 100%|██████████| 189/189 [01:50<00:00,  1.71it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.46it/s]
# 2024-10-31 23:18:39,210 - logging_config - INFO - Epoch [44/800], Train Loss: 1.3651, Val Loss: 1.4596, Val Accuracy: 0.5391
# Training: 100%|██████████| 189/189 [01:48<00:00,  1.75it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.46it/s]
# 2024-10-31 23:20:46,791 - logging_config - INFO - Epoch [45/800], Train Loss: 1.3538, Val Loss: 1.4382, Val Accuracy: 0.5236
# Training: 100%|██████████| 189/189 [01:46<00:00,  1.77it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.47it/s]
# 2024-10-31 23:22:52,774 - logging_config - INFO - Epoch [46/800], Train Loss: 1.3503, Val Loss: 1.4763, Val Accuracy: 0.4826
# Training: 100%|██████████| 189/189 [01:49<00:00,  1.73it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.48it/s]
# 2024-10-31 23:25:01,515 - logging_config - INFO - Epoch [47/800], Train Loss: 1.3467, Val Loss: 1.4359, Val Accuracy: 0.4755
# Training: 100%|██████████| 189/189 [01:49<00:00,  1.73it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.43it/s]
# 2024-10-31 23:27:10,850 - logging_config - INFO - Epoch [48/800], Train Loss: 1.3385, Val Loss: 1.3974, Val Accuracy: 0.5854
# Training: 100%|██████████| 189/189 [01:48<00:00,  1.74it/s]
# Validation: 100%|██████████| 48/48 [00:20<00:00,  2.38it/s]
# 2024-10-31 23:29:19,795 - logging_config - INFO - Epoch [49/800], Train Loss: 1.3340, Val Loss: 1.3882, Val Accuracy: 0.5314
# Training: 100%|██████████| 189/189 [01:47<00:00,  1.76it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.42it/s]
# 2024-10-31 23:31:26,848 - logging_config - INFO - Epoch [50/800], Train Loss: 1.3282, Val Loss: 1.4658, Val Accuracy: 0.5207
# Training: 100%|██████████| 189/189 [01:50<00:00,  1.71it/s]
# Validation: 100%|██████████| 48/48 [00:20<00:00,  2.29it/s]
# 2024-10-31 23:33:38,400 - logging_config - INFO - Epoch [51/800], Train Loss: 1.3258, Val Loss: 1.4241, Val Accuracy: 0.5857
# Training: 100%|██████████| 189/189 [01:49<00:00,  1.73it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.53it/s]
# 2024-10-31 23:35:46,863 - logging_config - INFO - Epoch [52/800], Train Loss: 1.3307, Val Loss: 1.5043, Val Accuracy: 0.5330
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.79it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.53it/s]
# 2024-10-31 23:37:51,269 - logging_config - INFO - Epoch [53/800], Train Loss: 1.3353, Val Loss: 1.4024, Val Accuracy: 0.4865
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.80it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.51it/s]
# 2024-10-31 23:39:55,664 - logging_config - INFO - Epoch [54/800], Train Loss: 1.3319, Val Loss: 1.4144, Val Accuracy: 0.5181
# Training: 100%|██████████| 189/189 [01:46<00:00,  1.78it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.47it/s]
# 2024-10-31 23:42:01,117 - logging_config - INFO - Epoch [55/800], Train Loss: 1.3322, Val Loss: 1.5079, Val Accuracy: 0.4813
# Training: 100%|██████████| 189/189 [01:46<00:00,  1.77it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.45it/s]
# 2024-10-31 23:44:07,251 - logging_config - INFO - Epoch [56/800], Train Loss: 1.3349, Val Loss: 1.6364, Val Accuracy: 0.4885
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.80it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.40it/s]
# 2024-10-31 23:46:12,362 - logging_config - INFO - Epoch [57/800], Train Loss: 1.3663, Val Loss: 1.5494, Val Accuracy: 0.5461
# Training: 100%|██████████| 189/189 [01:47<00:00,  1.76it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.46it/s]
# 2024-10-31 23:48:19,432 - logging_config - INFO - Epoch [58/800], Train Loss: 1.3390, Val Loss: 1.6112, Val Accuracy: 0.4633
# Training: 100%|██████████| 189/189 [01:47<00:00,  1.76it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.52it/s]
# 2024-10-31 23:50:25,702 - logging_config - INFO - Epoch [59/800], Train Loss: 1.3363, Val Loss: 1.6127, Val Accuracy: 0.4281
# Training: 100%|██████████| 189/189 [01:48<00:00,  1.74it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.47it/s]
# 2024-10-31 23:52:33,787 - logging_config - INFO - Epoch [60/800], Train Loss: 1.3358, Val Loss: 1.6247, Val Accuracy: 0.5973
# Training: 100%|██████████| 189/189 [01:48<00:00,  1.75it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.53it/s]
# 2024-10-31 23:54:41,108 - logging_config - INFO - Epoch [61/800], Train Loss: 1.3342, Val Loss: 1.7173, Val Accuracy: 0.4911
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.78it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.53it/s]
# 2024-10-31 23:56:45,967 - logging_config - INFO - Epoch [62/800], Train Loss: 1.3440, Val Loss: 1.6634, Val Accuracy: 0.4056
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.79it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.53it/s]
# 2024-10-31 23:58:50,223 - logging_config - INFO - Epoch [63/800], Train Loss: 1.3423, Val Loss: 1.4798, Val Accuracy: 0.5916
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.79it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.53it/s]
# 2024-11-01 00:00:54,710 - logging_config - INFO - Epoch [64/800], Train Loss: 1.3434, Val Loss: 1.6392, Val Accuracy: 0.4636
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.79it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.54it/s]
# 2024-11-01 00:02:59,129 - logging_config - INFO - Epoch [65/800], Train Loss: 1.3371, Val Loss: 1.5116, Val Accuracy: 0.5401
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.79it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.53it/s]
# 2024-11-01 00:05:03,618 - logging_config - INFO - Epoch [66/800], Train Loss: 1.3483, Val Loss: 1.5285, Val Accuracy: 0.5069
# Training: 100%|██████████| 189/189 [01:51<00:00,  1.70it/s]
# Validation: 100%|██████████| 48/48 [00:22<00:00,  2.14it/s]
# 2024-11-01 00:07:17,117 - logging_config - INFO - Epoch [67/800], Train Loss: 1.3400, Val Loss: 1.4742, Val Accuracy: 0.5232
# Training: 100%|██████████| 189/189 [02:04<00:00,  1.51it/s]
# Validation: 100%|██████████| 48/48 [00:22<00:00,  2.13it/s]
# 2024-11-01 00:09:44,518 - logging_config - INFO - Epoch [68/800], Train Loss: 1.3371, Val Loss: 1.6563, Val Accuracy: 0.5154
# Training: 100%|██████████| 189/189 [02:04<00:00,  1.52it/s]
# Validation: 100%|██████████| 48/48 [00:22<00:00,  2.14it/s]
# 2024-11-01 00:12:11,619 - logging_config - INFO - Epoch [69/800], Train Loss: 1.3402, Val Loss: 1.6226, Val Accuracy: 0.5572
# Training: 100%|██████████| 189/189 [02:04<00:00,  1.51it/s]
# Validation: 100%|██████████| 48/48 [00:22<00:00,  2.13it/s]
# 2024-11-01 00:14:38,985 - logging_config - INFO - Epoch [70/800], Train Loss: 1.3329, Val Loss: 1.6435, Val Accuracy: 0.5210
# Training: 100%|██████████| 189/189 [02:05<00:00,  1.51it/s]
# Validation: 100%|██████████| 48/48 [00:22<00:00,  2.12it/s]
# 2024-11-01 00:17:06,898 - logging_config - INFO - Epoch [71/800], Train Loss: 1.3328, Val Loss: 1.6183, Val Accuracy: 0.5445
# Training: 100%|██████████| 189/189 [02:05<00:00,  1.51it/s]
# Validation: 100%|██████████| 48/48 [00:22<00:00,  2.12it/s]
# 2024-11-01 00:19:34,923 - logging_config - INFO - Epoch [72/800], Train Loss: 1.3519, Val Loss: 1.6940, Val Accuracy: 0.3798
# Training: 100%|██████████| 189/189 [02:05<00:00,  1.51it/s]
# Validation: 100%|██████████| 48/48 [00:22<00:00,  2.14it/s]
# 2024-11-01 00:22:02,402 - logging_config - INFO - Epoch [73/800], Train Loss: 1.3751, Val Loss: 1.5967, Val Accuracy: 0.5323
# Training: 100%|██████████| 189/189 [02:05<00:00,  1.51it/s]
# Validation: 100%|██████████| 48/48 [00:22<00:00,  2.14it/s]
# 2024-11-01 00:24:30,248 - logging_config - INFO - Epoch [74/800], Train Loss: 1.3478, Val Loss: 1.5739, Val Accuracy: 0.4477
# Training: 100%|██████████| 189/189 [02:06<00:00,  1.50it/s]
# Validation: 100%|██████████| 48/48 [00:21<00:00,  2.19it/s]
# 2024-11-01 00:26:58,613 - logging_config - INFO - Epoch [75/800], Train Loss: 1.3905, Val Loss: 1.6927, Val Accuracy: 0.4512
# Training: 100%|██████████| 189/189 [02:05<00:00,  1.50it/s]
# Validation: 100%|██████████| 48/48 [00:22<00:00,  2.14it/s]
# 2024-11-01 00:29:26,743 - logging_config - INFO - Epoch [76/800], Train Loss: 1.3501, Val Loss: 1.4542, Val Accuracy: 0.5472
# Training: 100%|██████████| 189/189 [02:04<00:00,  1.51it/s]
# Validation: 100%|██████████| 48/48 [00:22<00:00,  2.15it/s]
# 2024-11-01 00:31:53,900 - logging_config - INFO - Epoch [77/800], Train Loss: 1.3365, Val Loss: 1.7600, Val Accuracy: 0.4113
# Training: 100%|██████████| 189/189 [02:04<00:00,  1.52it/s]
# Validation: 100%|██████████| 48/48 [00:22<00:00,  2.13it/s]
# 2024-11-01 00:34:21,034 - logging_config - INFO - Epoch [78/800], Train Loss: 1.3338, Val Loss: 1.6928, Val Accuracy: 0.4464
# Training: 100%|██████████| 189/189 [02:04<00:00,  1.52it/s]
# Validation: 100%|██████████| 48/48 [00:22<00:00,  2.14it/s]
# 2024-11-01 00:36:48,096 - logging_config - INFO - Epoch [79/800], Train Loss: 1.3343, Val Loss: 1.7258, Val Accuracy: 0.5086
# Training: 100%|██████████| 189/189 [02:04<00:00,  1.52it/s]
# Validation: 100%|██████████| 48/48 [00:22<00:00,  2.13it/s]
# 2024-11-01 00:39:15,220 - logging_config - INFO - Epoch [80/800], Train Loss: 1.3447, Val Loss: 1.5033, Val Accuracy: 0.4722
# Training: 100%|██████████| 189/189 [02:04<00:00,  1.51it/s]
# Validation: 100%|██████████| 48/48 [00:22<00:00,  2.15it/s]
# 2024-11-01 00:41:42,422 - logging_config - INFO - Epoch [81/800], Train Loss: 1.3368, Val Loss: 1.5172, Val Accuracy: 0.5095
# Training: 100%|██████████| 189/189 [02:04<00:00,  1.52it/s]
# Validation: 100%|██████████| 48/48 [00:22<00:00,  2.14it/s]
# 2024-11-01 00:44:09,295 - logging_config - INFO - Epoch [82/800], Train Loss: 1.3351, Val Loss: 1.6751, Val Accuracy: 0.5925
# Training: 100%|██████████| 189/189 [02:04<00:00,  1.51it/s]
# Validation: 100%|██████████| 48/48 [00:22<00:00,  2.13it/s]
# 2024-11-01 00:46:36,741 - logging_config - INFO - Epoch [83/800], Train Loss: 1.3304, Val Loss: 1.6538, Val Accuracy: 0.4796
# Training: 100%|██████████| 189/189 [02:04<00:00,  1.52it/s]
# Validation: 100%|██████████| 48/48 [00:22<00:00,  2.14it/s]
# 2024-11-01 00:49:03,660 - logging_config - INFO - Epoch [84/800], Train Loss: 1.3334, Val Loss: 1.4519, Val Accuracy: 0.5508
# Training: 100%|██████████| 189/189 [02:04<00:00,  1.52it/s]
# Validation: 100%|██████████| 48/48 [00:22<00:00,  2.15it/s]
# 2024-11-01 00:51:30,625 - logging_config - INFO - Epoch [85/800], Train Loss: 1.3281, Val Loss: 1.5114, Val Accuracy: 0.5387
# Training: 100%|██████████| 189/189 [02:04<00:00,  1.52it/s]
# Validation: 100%|██████████| 48/48 [00:22<00:00,  2.13it/s]
# 2024-11-01 00:53:57,850 - logging_config - INFO - Epoch [86/800], Train Loss: 1.3255, Val Loss: 1.6868, Val Accuracy: 0.5505
# Training: 100%|██████████| 189/189 [02:04<00:00,  1.51it/s]
# Validation: 100%|██████████| 48/48 [00:22<00:00,  2.09it/s]
# 2024-11-01 00:56:25,660 - logging_config - INFO - Epoch [87/800], Train Loss: 1.3245, Val Loss: 1.6919, Val Accuracy: 0.5478
# Training: 100%|██████████| 189/189 [02:05<00:00,  1.51it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.43it/s]
# 2024-11-01 00:58:50,492 - logging_config - INFO - Epoch [88/800], Train Loss: 1.3225, Val Loss: 1.5881, Val Accuracy: 0.5062
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.79it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.54it/s]
# 2024-11-01 01:00:54,868 - logging_config - INFO - Epoch [89/800], Train Loss: 1.3285, Val Loss: 1.7406, Val Accuracy: 0.5135
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.79it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.55it/s]
# 2024-11-01 01:02:59,228 - logging_config - INFO - Epoch [90/800], Train Loss: 1.3284, Val Loss: 1.7027, Val Accuracy: 0.4743
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.79it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.53it/s]
# 2024-11-01 01:05:03,755 - logging_config - INFO - Epoch [91/800], Train Loss: 1.3194, Val Loss: 1.5516, Val Accuracy: 0.5015
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.79it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.54it/s]
# 2024-11-01 01:07:08,043 - logging_config - INFO - Epoch [92/800], Train Loss: 1.3163, Val Loss: 1.5862, Val Accuracy: 0.5238
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.80it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.54it/s]
# 2024-11-01 01:09:12,243 - logging_config - INFO - Epoch [93/800], Train Loss: 1.3143, Val Loss: 1.5833, Val Accuracy: 0.5267
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.79it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.54it/s]
# 2024-11-01 01:11:16,604 - logging_config - INFO - Epoch [94/800], Train Loss: 1.3168, Val Loss: 1.5893, Val Accuracy: 0.5037
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.80it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.53it/s]
# 2024-11-01 01:13:20,844 - logging_config - INFO - Epoch [95/800], Train Loss: 1.3174, Val Loss: 1.5948, Val Accuracy: 0.4763
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.79it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.54it/s]
# 2024-11-01 01:15:25,148 - logging_config - INFO - Epoch [96/800], Train Loss: 1.3250, Val Loss: 1.7022, Val Accuracy: 0.6002
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.79it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.53it/s]
# 2024-11-01 01:17:29,458 - logging_config - INFO - Epoch [97/800], Train Loss: 1.3137, Val Loss: 1.6032, Val Accuracy: 0.5241
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.79it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.53it/s]
# 2024-11-01 01:19:33,987 - logging_config - INFO - Epoch [98/800], Train Loss: 1.3073, Val Loss: 1.7578, Val Accuracy: 0.5351
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.80it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.53it/s]
# 2024-11-01 01:21:38,244 - logging_config - INFO - Epoch [99/800], Train Loss: 1.3102, Val Loss: 1.8909, Val Accuracy: 0.5514
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.79it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.53it/s]
# 2024-11-01 01:23:42,859 - logging_config - INFO - Epoch [100/800], Train Loss: 1.3065, Val Loss: 1.7131, Val Accuracy: 0.5408
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.79it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.55it/s]
# 2024-11-01 01:25:47,242 - logging_config - INFO - Epoch [101/800], Train Loss: 1.3013, Val Loss: 1.8491, Val Accuracy: 0.5616
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.79it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.53it/s]
# 2024-11-01 01:27:51,757 - logging_config - INFO - Epoch [102/800], Train Loss: 1.2992, Val Loss: 1.7780, Val Accuracy: 0.5253
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.79it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.55it/s]
# 2024-11-01 01:29:56,039 - logging_config - INFO - Epoch [103/800], Train Loss: 1.3186, Val Loss: 2.1386, Val Accuracy: 0.5161
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.79it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.53it/s]
# 2024-11-01 01:32:00,511 - logging_config - INFO - Epoch [104/800], Train Loss: 1.3023, Val Loss: 1.8644, Val Accuracy: 0.5371
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.79it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.53it/s]
# 2024-11-01 01:34:05,011 - logging_config - INFO - Epoch [105/800], Train Loss: 1.2922, Val Loss: 1.7823, Val Accuracy: 0.5183
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.79it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.53it/s]
# 2024-11-01 01:36:09,443 - logging_config - INFO - Epoch [106/800], Train Loss: 1.2829, Val Loss: 1.8195, Val Accuracy: 0.5783
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.79it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.55it/s]
# 2024-11-01 01:38:13,906 - logging_config - INFO - Epoch [107/800], Train Loss: 1.2847, Val Loss: 1.8694, Val Accuracy: 0.5468
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.79it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.53it/s]
# 2024-11-01 01:40:18,207 - logging_config - INFO - Epoch [108/800], Train Loss: 1.3065, Val Loss: 2.3159, Val Accuracy: 0.5644
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.79it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.53it/s]
# 2024-11-01 01:42:22,625 - logging_config - INFO - Epoch [109/800], Train Loss: 1.3104, Val Loss: 1.7617, Val Accuracy: 0.4797
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.80it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.53it/s]
# 2024-11-01 01:44:26,704 - logging_config - INFO - Epoch [110/800], Train Loss: 1.3165, Val Loss: 1.8712, Val Accuracy: 0.6088
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.79it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.52it/s]
# 2024-11-01 01:46:31,276 - logging_config - INFO - Epoch [111/800], Train Loss: 1.3154, Val Loss: 1.7166, Val Accuracy: 0.4951
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.80it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.54it/s]
# 2024-11-01 01:48:35,262 - logging_config - INFO - Epoch [112/800], Train Loss: 1.3070, Val Loss: 1.8198, Val Accuracy: 0.5321
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.79it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.52it/s]
# 2024-11-01 01:50:39,915 - logging_config - INFO - Epoch [113/800], Train Loss: 1.3117, Val Loss: 1.7533, Val Accuracy: 0.5266
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.80it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.55it/s]
# 2024-11-01 01:52:43,913 - logging_config - INFO - Epoch [114/800], Train Loss: 1.2836, Val Loss: 2.0293, Val Accuracy: 0.5225
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.80it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.54it/s]
# 2024-11-01 01:54:47,980 - logging_config - INFO - Epoch [115/800], Train Loss: 1.2749, Val Loss: 1.8294, Val Accuracy: 0.5708
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.79it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.54it/s]
# 2024-11-01 01:56:52,254 - logging_config - INFO - Epoch [116/800], Train Loss: 1.2722, Val Loss: 2.1544, Val Accuracy: 0.5782
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.81it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.54it/s]
# 2024-11-01 01:58:55,686 - logging_config - INFO - Epoch [117/800], Train Loss: 1.2711, Val Loss: 1.9823, Val Accuracy: 0.5547
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.80it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.54it/s]
# 2024-11-01 02:00:59,421 - logging_config - INFO - Epoch [118/800], Train Loss: 1.2691, Val Loss: 2.0175, Val Accuracy: 0.5965
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.80it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.54it/s]
# 2024-11-01 02:03:03,327 - logging_config - INFO - Epoch [119/800], Train Loss: 1.2767, Val Loss: 2.1019, Val Accuracy: 0.5837
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.80it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.57it/s]
# 2024-11-01 02:05:06,916 - logging_config - INFO - Epoch [120/800], Train Loss: 1.2705, Val Loss: 2.0054, Val Accuracy: 0.5827
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.80it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.56it/s]
# 2024-11-01 02:07:10,439 - logging_config - INFO - Epoch [121/800], Train Loss: 1.2564, Val Loss: 2.2051, Val Accuracy: 0.5686
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.79it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.55it/s]
# 2024-11-01 02:09:14,608 - logging_config - INFO - Epoch [122/800], Train Loss: 1.2453, Val Loss: 2.3036, Val Accuracy: 0.6100
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.81it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.54it/s]
# 2024-11-01 02:11:17,809 - logging_config - INFO - Epoch [123/800], Train Loss: 1.2371, Val Loss: 2.3914, Val Accuracy: 0.5955
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.82it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.56it/s]
# 2024-11-01 02:13:20,673 - logging_config - INFO - Epoch [124/800], Train Loss: 1.2335, Val Loss: 2.3109, Val Accuracy: 0.5743
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.82it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.54it/s]
# 2024-11-01 02:15:23,230 - logging_config - INFO - Epoch [125/800], Train Loss: 1.2474, Val Loss: 2.4502, Val Accuracy: 0.6112
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.83it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.54it/s]
# 2024-11-01 02:17:25,538 - logging_config - INFO - Epoch [126/800], Train Loss: 1.2629, Val Loss: 2.3142, Val Accuracy: 0.5250
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.80it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.54it/s]
# 2024-11-01 02:19:29,485 - logging_config - INFO - Epoch [127/800], Train Loss: 1.2529, Val Loss: 2.5509, Val Accuracy: 0.5906
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.81it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.54it/s]
# 2024-11-01 02:21:32,694 - logging_config - INFO - Epoch [128/800], Train Loss: 1.2379, Val Loss: 2.6284, Val Accuracy: 0.5821
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.82it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.55it/s]
# 2024-11-01 02:23:35,495 - logging_config - INFO - Epoch [129/800], Train Loss: 1.2269, Val Loss: 2.6407, Val Accuracy: 0.6105
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.83it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.53it/s]
# 2024-11-01 02:25:37,721 - logging_config - INFO - Epoch [130/800], Train Loss: 1.2138, Val Loss: 2.7871, Val Accuracy: 0.6173
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.82it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.57it/s]
# 2024-11-01 02:27:40,189 - logging_config - INFO - Epoch [131/800], Train Loss: 1.2117, Val Loss: 2.6166, Val Accuracy: 0.5977
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.81it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.53it/s]
# 2024-11-01 02:29:43,309 - logging_config - INFO - Epoch [132/800], Train Loss: 1.2031, Val Loss: 2.9789, Val Accuracy: 0.6064
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.80it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.55it/s]
# 2024-11-01 02:31:47,404 - logging_config - INFO - Epoch [133/800], Train Loss: 1.2030, Val Loss: 2.6869, Val Accuracy: 0.5902
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.81it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.53it/s]
# 2024-11-01 02:33:50,629 - logging_config - INFO - Epoch [134/800], Train Loss: 1.2363, Val Loss: 2.6323, Val Accuracy: 0.6058
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.81it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.55it/s]
# 2024-11-01 02:35:54,042 - logging_config - INFO - Epoch [135/800], Train Loss: 1.2693, Val Loss: 2.8239, Val Accuracy: 0.5675
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.81it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.54it/s]
# 2024-11-01 02:37:57,312 - logging_config - INFO - Epoch [136/800], Train Loss: 1.2245, Val Loss: 2.7715, Val Accuracy: 0.5675
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.81it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.59it/s]
# 2024-11-01 02:40:00,427 - logging_config - INFO - Epoch [137/800], Train Loss: 1.2091, Val Loss: 3.4163, Val Accuracy: 0.6252
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.80it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.53it/s]
# 2024-11-01 02:42:04,243 - logging_config - INFO - Epoch [138/800], Train Loss: 1.1905, Val Loss: 3.1995, Val Accuracy: 0.6275
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.82it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.57it/s]
# 2024-11-01 02:44:06,861 - logging_config - INFO - Epoch [139/800], Train Loss: 1.1768, Val Loss: 3.2186, Val Accuracy: 0.6120
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.82it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.56it/s]
# 2024-11-01 02:46:09,749 - logging_config - INFO - Epoch [140/800], Train Loss: 1.1691, Val Loss: 3.1477, Val Accuracy: 0.6244
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.82it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.58it/s]
# 2024-11-01 02:48:11,971 - logging_config - INFO - Epoch [141/800], Train Loss: 1.1627, Val Loss: 3.2230, Val Accuracy: 0.6340
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.82it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.58it/s]
# 2024-11-01 02:50:14,610 - logging_config - INFO - Epoch [142/800], Train Loss: 1.1582, Val Loss: 3.1425, Val Accuracy: 0.6255
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.82it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.57it/s]
# 2024-11-01 02:52:17,211 - logging_config - INFO - Epoch [143/800], Train Loss: 1.1866, Val Loss: 2.9885, Val Accuracy: 0.5425
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.82it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.60it/s]
# 2024-11-01 02:54:19,531 - logging_config - INFO - Epoch [144/800], Train Loss: 1.2444, Val Loss: 2.8317, Val Accuracy: 0.5712
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.81it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.55it/s]
# 2024-11-01 02:56:22,537 - logging_config - INFO - Epoch [145/800], Train Loss: 1.1795, Val Loss: 3.1810, Val Accuracy: 0.6197
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.81it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.60it/s]
# 2024-11-01 02:58:25,389 - logging_config - INFO - Epoch [146/800], Train Loss: 1.1638, Val Loss: 3.0399, Val Accuracy: 0.6437
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.82it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.58it/s]
# 2024-11-01 03:00:27,580 - logging_config - INFO - Epoch [147/800], Train Loss: 1.1616, Val Loss: 5.1308, Val Accuracy: 0.6886
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.82it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.58it/s]
# 2024-11-01 03:02:30,103 - logging_config - INFO - Epoch [148/800], Train Loss: 1.2674, Val Loss: 2.9107, Val Accuracy: 0.5525
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.82it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.58it/s]
# 2024-11-01 03:04:32,798 - logging_config - INFO - Epoch [149/800], Train Loss: 1.1981, Val Loss: 2.8426, Val Accuracy: 0.6055
# Training: 100%|██████████| 189/189 [01:42<00:00,  1.84it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.60it/s]
# 2024-11-01 03:06:34,140 - logging_config - INFO - Epoch [150/800], Train Loss: 1.1618, Val Loss: 3.3041, Val Accuracy: 0.6125
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.80it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.51it/s]
# 2024-11-01 03:08:38,007 - logging_config - INFO - Epoch [151/800], Train Loss: 1.1493, Val Loss: 3.2696, Val Accuracy: 0.6385
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.79it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.58it/s]
# 2024-11-01 03:10:41,962 - logging_config - INFO - Epoch [152/800], Train Loss: 1.1324, Val Loss: 3.1477, Val Accuracy: 0.6240
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.82it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.60it/s]
# 2024-11-01 03:12:44,346 - logging_config - INFO - Epoch [153/800], Train Loss: 1.1352, Val Loss: 3.4249, Val Accuracy: 0.6297
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.82it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.56it/s]
# 2024-11-01 03:14:47,169 - logging_config - INFO - Epoch [154/800], Train Loss: 1.1115, Val Loss: 3.3732, Val Accuracy: 0.6245
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.82it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.58it/s]
# 2024-11-01 03:16:49,764 - logging_config - INFO - Epoch [155/800], Train Loss: 1.1368, Val Loss: 3.7011, Val Accuracy: 0.5910
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.80it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.55it/s]
# 2024-11-01 03:18:53,834 - logging_config - INFO - Epoch [156/800], Train Loss: 1.1540, Val Loss: 3.5953, Val Accuracy: 0.6392
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.83it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.59it/s]
# 2024-11-01 03:20:55,812 - logging_config - INFO - Epoch [157/800], Train Loss: 1.1212, Val Loss: 3.8573, Val Accuracy: 0.6060
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.83it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.52it/s]
# 2024-11-01 03:22:58,430 - logging_config - INFO - Epoch [158/800], Train Loss: 1.0937, Val Loss: 3.6886, Val Accuracy: 0.6350
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.81it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.58it/s]
# 2024-11-01 03:25:01,198 - logging_config - INFO - Epoch [159/800], Train Loss: 1.0763, Val Loss: 4.1023, Val Accuracy: 0.6215
# Training: 100%|██████████| 189/189 [01:42<00:00,  1.84it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.58it/s]
# 2024-11-01 03:27:02,761 - logging_config - INFO - Epoch [160/800], Train Loss: 1.0755, Val Loss: 3.8855, Val Accuracy: 0.6399
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.83it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.57it/s]
# 2024-11-01 03:29:04,451 - logging_config - INFO - Epoch [161/800], Train Loss: 1.0916, Val Loss: 3.9590, Val Accuracy: 0.5997
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.80it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.55it/s]
# 2024-11-01 03:31:08,181 - logging_config - INFO - Epoch [162/800], Train Loss: 1.1416, Val Loss: 3.7775, Val Accuracy: 0.6130
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.81it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.60it/s]
# 2024-11-01 03:33:10,917 - logging_config - INFO - Epoch [163/800], Train Loss: 1.1046, Val Loss: 4.3440, Val Accuracy: 0.6114
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.81it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.56it/s]
# 2024-11-01 03:35:14,139 - logging_config - INFO - Epoch [164/800], Train Loss: 1.0979, Val Loss: 4.2368, Val Accuracy: 0.6495
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.82it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.58it/s]
# 2024-11-01 03:37:16,403 - logging_config - INFO - Epoch [165/800], Train Loss: 1.0659, Val Loss: 4.3311, Val Accuracy: 0.6510
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.82it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.54it/s]
# 2024-11-01 03:39:19,004 - logging_config - INFO - Epoch [166/800], Train Loss: 1.0501, Val Loss: 4.4875, Val Accuracy: 0.6510
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.81it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.53it/s]
# 2024-11-01 03:41:22,264 - logging_config - INFO - Epoch [167/800], Train Loss: 1.0511, Val Loss: 4.9716, Val Accuracy: 0.6520
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.81it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.58it/s]
# 2024-11-01 03:43:25,116 - logging_config - INFO - Epoch [168/800], Train Loss: 1.0301, Val Loss: 4.9099, Val Accuracy: 0.6466
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.83it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.56it/s]
# 2024-11-01 03:45:27,309 - logging_config - INFO - Epoch [169/800], Train Loss: 1.0191, Val Loss: 5.3699, Val Accuracy: 0.6820
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.82it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.54it/s]
# 2024-11-01 03:47:29,830 - logging_config - INFO - Epoch [170/800], Train Loss: 1.0266, Val Loss: 5.2189, Val Accuracy: 0.6626
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.82it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.55it/s]
# 2024-11-01 03:49:32,601 - logging_config - INFO - Epoch [171/800], Train Loss: 1.0113, Val Loss: 5.2511, Val Accuracy: 0.6349
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.83it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.58it/s]
# 2024-11-01 03:51:34,517 - logging_config - INFO - Epoch [172/800], Train Loss: 0.9948, Val Loss: 5.5305, Val Accuracy: 0.6864
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.83it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.59it/s]
# 2024-11-01 03:53:36,413 - logging_config - INFO - Epoch [173/800], Train Loss: 1.0070, Val Loss: 5.1811, Val Accuracy: 0.6421
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.82it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.55it/s]
# 2024-11-01 03:55:39,042 - logging_config - INFO - Epoch [174/800], Train Loss: 1.2132, Val Loss: 3.2850, Val Accuracy: 0.5484
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.80it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.55it/s]
# 2024-11-01 03:57:42,841 - logging_config - INFO - Epoch [175/800], Train Loss: 1.1293, Val Loss: 3.7644, Val Accuracy: 0.5869
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.83it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.60it/s]
# 2024-11-01 03:59:44,350 - logging_config - INFO - Epoch [176/800], Train Loss: 1.0841, Val Loss: 3.2060, Val Accuracy: 0.6073
# Training: 100%|██████████| 189/189 [01:42<00:00,  1.84it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.59it/s]
# 2024-11-01 04:01:45,769 - logging_config - INFO - Epoch [177/800], Train Loss: 1.1693, Val Loss: 4.2649, Val Accuracy: 0.6376
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.83it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.57it/s]
# 2024-11-01 04:03:47,605 - logging_config - INFO - Epoch [178/800], Train Loss: 1.0728, Val Loss: 5.0036, Val Accuracy: 0.6481
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.82it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.53it/s]
# 2024-11-01 04:05:50,603 - logging_config - INFO - Epoch [179/800], Train Loss: 1.0321, Val Loss: 5.0169, Val Accuracy: 0.6649
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.82it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.56it/s]
# 2024-11-01 04:07:53,089 - logging_config - INFO - Epoch [180/800], Train Loss: 1.0018, Val Loss: 5.8932, Val Accuracy: 0.6869
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.83it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.58it/s]
# 2024-11-01 04:09:54,896 - logging_config - INFO - Epoch [181/800], Train Loss: 1.1358, Val Loss: 3.0757, Val Accuracy: 0.6108
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.81it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.60it/s]
# 2024-11-01 04:11:57,824 - logging_config - INFO - Epoch [182/800], Train Loss: 1.1801, Val Loss: 3.2499, Val Accuracy: 0.5753
# Training: 100%|██████████| 189/189 [01:42<00:00,  1.84it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.59it/s]
# 2024-11-01 04:13:59,141 - logging_config - INFO - Epoch [183/800], Train Loss: 1.1035, Val Loss: 4.6275, Val Accuracy: 0.6520
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.82it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.58it/s]
# 2024-11-01 04:16:01,523 - logging_config - INFO - Epoch [184/800], Train Loss: 1.0578, Val Loss: 4.6001, Val Accuracy: 0.6431
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.82it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.58it/s]
# 2024-11-01 04:18:04,119 - logging_config - INFO - Epoch [185/800], Train Loss: 1.0164, Val Loss: 5.4512, Val Accuracy: 0.6647
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.82it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.57it/s]
# 2024-11-01 04:20:06,820 - logging_config - INFO - Epoch [186/800], Train Loss: 0.9904, Val Loss: 5.9788, Val Accuracy: 0.6899
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.83it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.55it/s]
# 2024-11-01 04:22:09,189 - logging_config - INFO - Epoch [187/800], Train Loss: 0.9735, Val Loss: 6.3395, Val Accuracy: 0.6680
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.82it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.60it/s]
# 2024-11-01 04:24:11,325 - logging_config - INFO - Epoch [188/800], Train Loss: 0.9732, Val Loss: 6.8924, Val Accuracy: 0.6847
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.83it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.60it/s]
# 2024-11-01 04:26:12,884 - logging_config - INFO - Epoch [189/800], Train Loss: 0.9603, Val Loss: 7.0929, Val Accuracy: 0.6703
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.83it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.61it/s]
# 2024-11-01 04:28:14,323 - logging_config - INFO - Epoch [190/800], Train Loss: 0.9399, Val Loss: 7.4615, Val Accuracy: 0.6831
# Training: 100%|██████████| 189/189 [01:42<00:00,  1.84it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.60it/s]
# 2024-11-01 04:30:15,356 - logging_config - INFO - Epoch [191/800], Train Loss: 0.9301, Val Loss: 7.7152, Val Accuracy: 0.6955
# Training: 100%|██████████| 189/189 [01:43<00:00,  1.83it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.60it/s]
# 2024-11-01 04:32:16,887 - logging_config - INFO - Epoch [192/800], Train Loss: 0.9402, Val Loss: 7.4763, Val Accuracy: 0.6986
# ...
# Training: 100%|██████████| 189/189 [01:40<00:00,  1.89it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.65it/s]
# 2024-11-01 07:58:45,414 - logging_config - INFO - Epoch [294/800], Train Loss: 0.6662, Val Loss: 18.7591, Val Accuracy: 0.7847
# 2024-11-01 07:58:45,605 - logging_config - INFO - Best model saved with accuracy: 0.7847
# Training: 100%|██████████| 189/189 [01:40<00:00,  1.89it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.65it/s]
# 2024-11-01 08:00:43,750 - logging_config - INFO - Epoch [295/800], Train Loss: 0.6427, Val Loss: 20.1707, Val Accuracy: 0.7914
# 2024-11-01 08:00:43,950 - logging_config - INFO - Best model saved with accuracy: 0.7914
# Training: 100%|██████████| 189/189 [01:40<00:00,  1.88it/s]
# Validation: 100%|██████████| 48/48 [00:17<00:00,  2.68it/s]
# 2024-11-01 08:02:42,513 - logging_config - INFO - Epoch [296/800], Train Loss: 0.6256, Val Loss: 21.1765, Val Accuracy: 0.7916
# 2024-11-01 08:02:42,696 - logging_config - INFO - Best model saved with accuracy: 0.7916
# Training: 100%|██████████| 189/189 [01:40<00:00,  1.89it/s]
# Validation: 100%|██████████| 48/48 [00:17<00:00,  2.67it/s]
# 2024-11-01 08:04:40,837 - logging_config - INFO - Epoch [297/800], Train Loss: 0.6255, Val Loss: 21.5921, Val Accuracy: 0.7992
# 2024-11-01 08:04:41,017 - logging_config - INFO - Best model saved with accuracy: 0.7992
# Training: 100%|██████████| 189/189 [01:40<00:00,  1.88it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.66it/s]
# 2024-11-01 08:06:39,474 - logging_config - INFO - Epoch [298/800], Train Loss: 0.6276, Val Loss: 20.3850, Val Accuracy: 0.7738
# Training: 100%|██████████| 189/189 [01:40<00:00,  1.88it/s]
# Validation: 100%|██████████| 48/48 [00:17<00:00,  2.68it/s]
# 2024-11-01 08:08:37,949 - logging_config - INFO - Epoch [299/800], Train Loss: 0.7776, Val Loss: 10.2562, Val Accuracy: 0.6435
# Training: 100%|██████████| 189/189 [01:39<00:00,  1.89it/s]
# Validation: 100%|██████████| 48/48 [00:17<00:00,  2.67it/s]
# 2024-11-01 08:10:35,792 - logging_config - INFO - Epoch [300/800], Train Loss: 1.1787, Val Loss: 8.1743, Val Accuracy: 0.6146
# Training: 100%|██████████| 189/189 [01:39<00:00,  1.89it/s]
# Validation: 100%|██████████| 48/48 [00:17<00:00,  2.68it/s]
# 2024-11-01 08:12:33,536 - logging_config - INFO - Epoch [301/800], Train Loss: 1.0443, Val Loss: 7.1108, Val Accuracy: 0.6592
# Training: 100%|██████████| 189/189 [01:40<00:00,  1.89it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.66it/s]
# 2024-11-01 08:14:31,661 - logging_config - INFO - Epoch [302/800], Train Loss: 0.9428, Val Loss: 8.2520, Val Accuracy: 0.7104
# Training: 100%|██████████| 189/189 [01:40<00:00,  1.89it/s]
# Validation: 100%|██████████| 48/48 [00:17<00:00,  2.69it/s]
# 2024-11-01 08:16:29,680 - logging_config - INFO - Epoch [303/800], Train Loss: 0.8486, Val Loss: 9.4536, Val Accuracy: 0.7327
# Training: 100%|██████████| 189/189 [01:39<00:00,  1.90it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.66it/s]
# 2024-11-01 08:18:27,350 - logging_config - INFO - Epoch [304/800], Train Loss: 0.8023, Val Loss: 10.1510, Val Accuracy: 0.7426
# Training: 100%|██████████| 189/189 [01:39<00:00,  1.90it/s]
# Validation: 100%|██████████| 48/48 [00:17<00:00,  2.69it/s]
# 2024-11-01 08:20:24,818 - logging_config - INFO - Epoch [305/800], Train Loss: 0.7623, Val Loss: 11.5766, Val Accuracy: 0.7531
# Training: 100%|██████████| 189/189 [01:39<00:00,  1.89it/s]
# Validation: 100%|██████████| 48/48 [00:17<00:00,  2.68it/s]
# 2024-11-01 08:22:22,623 - logging_config - INFO - Epoch [306/800], Train Loss: 0.7206, Val Loss: 13.5868, Val Accuracy: 0.7650
# Training: 100%|██████████| 189/189 [01:40<00:00,  1.88it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.67it/s]
# 2024-11-01 08:24:21,439 - logging_config - INFO - Epoch [307/800], Train Loss: 0.6852, Val Loss: 15.7072, Val Accuracy: 0.7754
# Training: 100%|██████████| 189/189 [01:40<00:00,  1.89it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.66it/s]
# 2024-11-01 08:26:19,491 - logging_config - INFO - Epoch [308/800], Train Loss: 0.6598, Val Loss: 17.5540, Val Accuracy: 0.7892
# Training: 100%|██████████| 189/189 [01:39<00:00,  1.89it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.66it/s]
# 2024-11-01 08:28:17,452 - logging_config - INFO - Epoch [309/800], Train Loss: 0.6458, Val Loss: 18.5934, Val Accuracy: 0.7906
# Training: 100%|██████████| 189/189 [01:39<00:00,  1.89it/s]
# Validation: 100%|██████████| 48/48 [00:17<00:00,  2.67it/s]
# 2024-11-01 08:30:15,408 - logging_config - INFO - Epoch [310/800], Train Loss: 0.6354, Val Loss: 18.8732, Val Accuracy: 0.7822
# Training: 100%|██████████| 189/189 [01:40<00:00,  1.89it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.66it/s]
# 2024-11-01 08:32:13,706 - logging_config - INFO - Epoch [311/800], Train Loss: 0.6405, Val Loss: 19.8299, Val Accuracy: 0.7897
# Training: 100%|██████████| 189/189 [01:40<00:00,  1.87it/s]
# Validation: 100%|██████████| 48/48 [00:17<00:00,  2.67it/s]
# 2024-11-01 08:34:12,644 - logging_config - INFO - Epoch [312/800], Train Loss: 0.6156, Val Loss: 21.3944, Val Accuracy: 0.8047
# 2024-11-01 08:34:12,833 - logging_config - INFO - Best model saved with accuracy: 0.8047
# Training: 100%|██████████| 189/189 [01:40<00:00,  1.88it/s]
# Validation: 100%|██████████| 48/48 [00:17<00:00,  2.68it/s]
# 2024-11-01 08:36:11,032 - logging_config - INFO - Epoch [313/800], Train Loss: 0.5987, Val Loss: 21.1885, Val Accuracy: 0.8017
# Training: 100%|██████████| 189/189 [01:40<00:00,  1.88it/s]
# Validation: 100%|██████████| 48/48 [00:17<00:00,  2.68it/s]
# 2024-11-01 08:38:09,485 - logging_config - INFO - Epoch [314/800], Train Loss: 0.6002, Val Loss: 22.5080, Val Accuracy: 0.8029
# Training: 100%|██████████| 189/189 [01:40<00:00,  1.89it/s]
# Validation: 100%|██████████| 48/48 [00:17<00:00,  2.67it/s]
# 2024-11-01 08:40:07,484 - logging_config - INFO - Epoch [315/800], Train Loss: 0.7969, Val Loss: 13.4879, Val Accuracy: 0.7522
# Training: 100%|██████████| 189/189 [01:39<00:00,  1.90it/s]
# Validation: 100%|██████████| 48/48 [00:17<00:00,  2.69it/s]
# 2024-11-01 08:42:04,958 - logging_config - INFO - Epoch [316/800], Train Loss: 0.7297, Val Loss: 16.4807, Val Accuracy: 0.7826
# Training: 100%|██████████| 189/189 [01:39<00:00,  1.89it/s]
# Validation: 100%|██████████| 48/48 [00:17<00:00,  2.69it/s]
# 2024-11-01 08:44:02,646 - logging_config - INFO - Epoch [317/800], Train Loss: 0.6539, Val Loss: 18.9284, Val Accuracy: 0.7735
# Training: 100%|██████████| 189/189 [01:39<00:00,  1.90it/s]
# Validation: 100%|██████████| 48/48 [00:17<00:00,  2.68it/s]
# 2024-11-01 08:46:00,059 - logging_config - INFO - Epoch [318/800], Train Loss: 0.7966, Val Loss: 12.3009, Val Accuracy: 0.6260
# Training: 100%|██████████| 189/189 [01:39<00:00,  1.89it/s]
# Validation: 100%|██████████| 48/48 [00:17<00:00,  2.68it/s]
# 2024-11-01 08:47:57,785 - logging_config - INFO - Epoch [319/800], Train Loss: 0.9825, Val Loss: 10.0936, Val Accuracy: 0.6970
# Training: 100%|██████████| 189/189 [01:39<00:00,  1.90it/s]
# Validation: 100%|██████████| 48/48 [00:17<00:00,  2.68it/s]
# 2024-11-01 08:49:55,198 - logging_config - INFO - Epoch [320/800], Train Loss: 0.8125, Val Loss: 12.9218, Val Accuracy: 0.7458
# Training: 100%|██████████| 189/189 [01:39<00:00,  1.89it/s]
# Validation: 100%|██████████| 48/48 [00:17<00:00,  2.67it/s]
# 2024-11-01 08:51:53,184 - logging_config - INFO - Epoch [321/800], Train Loss: 0.7179, Val Loss: 15.2265, Val Accuracy: 0.7740
# Training: 100%|██████████| 189/189 [01:39<00:00,  1.90it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.66it/s]
# 2024-11-01 08:53:50,649 - logging_config - INFO - Epoch [322/800], Train Loss: 0.6653, Val Loss: 17.7114, Val Accuracy: 0.7879
# Training: 100%|██████████| 189/189 [01:39<00:00,  1.90it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.67it/s]
# 2024-11-01 08:55:48,264 - logging_config - INFO - Epoch [323/800], Train Loss: 0.6291, Val Loss: 19.9360, Val Accuracy: 0.7975
# Training: 100%|██████████| 189/189 [01:39<00:00,  1.90it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.65it/s]
# 2024-11-01 08:57:45,612 - logging_config - INFO - Epoch [324/800], Train Loss: 0.6058, Val Loss: 21.6602, Val Accuracy: 0.7980
# Training: 100%|██████████| 189/189 [01:39<00:00,  1.89it/s]
# Validation: 100%|██████████| 48/48 [00:17<00:00,  2.67it/s]
# 2024-11-01 08:59:43,531 - logging_config - INFO - Epoch [325/800], Train Loss: 0.5883, Val Loss: 22.9700, Val Accuracy: 0.8001
# Training: 100%|██████████| 189/189 [01:39<00:00,  1.89it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.67it/s]
# 2024-11-01 09:01:41,362 - logging_config - INFO - Epoch [326/800], Train Loss: 0.6740, Val Loss: 17.8660, Val Accuracy: 0.7753
# Training: 100%|██████████| 189/189 [01:39<00:00,  1.90it/s]
# Validation: 100%|██████████| 48/48 [00:17<00:00,  2.67it/s]
# 2024-11-01 09:03:38,894 - logging_config - INFO - Epoch [327/800], Train Loss: 0.6709, Val Loss: 17.5381, Val Accuracy: 0.7717
# Training: 100%|██████████| 189/189 [01:39<00:00,  1.90it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.66it/s]
# 2024-11-01 09:05:36,512 - logging_config - INFO - Epoch [328/800], Train Loss: 0.6651, Val Loss: 18.1785, Val Accuracy: 0.7682
# Training: 100%|██████████| 189/189 [01:39<00:00,  1.89it/s]
# Validation: 100%|██████████| 48/48 [00:17<00:00,  2.68it/s]
# 2024-11-01 09:07:34,302 - logging_config - INFO - Epoch [329/800], Train Loss: 0.6296, Val Loss: 20.8495, Val Accuracy: 0.7915
# Training: 100%|██████████| 189/189 [01:39<00:00,  1.90it/s]
# Validation: 100%|██████████| 48/48 [00:17<00:00,  2.67it/s]
# 2024-11-01 09:09:31,882 - logging_config - INFO - Epoch [330/800], Train Loss: 0.5869, Val Loss: 22.9991, Val Accuracy: 0.8050
# 2024-11-01 09:09:32,061 - logging_config - INFO - Best model saved with accuracy: 0.8050
# Training: 100%|██████████| 189/189 [01:39<00:00,  1.89it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.66it/s]
# 2024-11-01 09:11:30,062 - logging_config - INFO - Epoch [331/800], Train Loss: 0.5668, Val Loss: 24.9199, Val Accuracy: 0.8138
# 2024-11-01 09:11:30,256 - logging_config - INFO - Best model saved with accuracy: 0.8138
# Training: 100%|██████████| 189/189 [01:39<00:00,  1.89it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.66it/s]
# 2024-11-01 09:13:28,169 - logging_config - INFO - Epoch [332/800], Train Loss: 0.5608, Val Loss: 25.5087, Val Accuracy: 0.8083
# Training: 100%|██████████| 189/189 [01:39<00:00,  1.89it/s]
# Validation: 100%|██████████| 48/48 [00:17<00:00,  2.68it/s]
# 2024-11-01 09:15:25,936 - logging_config - INFO - Epoch [333/800], Train Loss: 0.5590, Val Loss: 25.1473, Val Accuracy: 0.7892
# Training: 100%|██████████| 189/189 [01:39<00:00,  1.89it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.65it/s]
# 2024-11-01 09:17:23,909 - logging_config - INFO - Epoch [334/800], Train Loss: 0.5889, Val Loss: 25.1280, Val Accuracy: 0.8131
# Training: 100%|██████████| 189/189 [01:40<00:00,  1.88it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.66it/s]
# 2024-11-01 09:19:22,343 - logging_config - INFO - Epoch [335/800], Train Loss: 0.5557, Val Loss: 25.5853, Val Accuracy: 0.8076
# Training: 100%|██████████| 189/189 [01:40<00:00,  1.88it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.66it/s]
# 2024-11-01 09:21:20,859 - logging_config - INFO - Epoch [336/800], Train Loss: 0.5453, Val Loss: 26.8548, Val Accuracy: 0.8214
# 2024-11-01 09:21:21,052 - logging_config - INFO - Best model saved with accuracy: 0.8214
# Training: 100%|██████████| 189/189 [01:40<00:00,  1.89it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.64it/s]
# 2024-11-01 09:23:19,338 - logging_config - INFO - Epoch [337/800], Train Loss: 0.5507, Val Loss: 27.8821, Val Accuracy: 0.8263
# 2024-11-01 09:23:19,529 - logging_config - INFO - Best model saved with accuracy: 0.8263
# Training: 100%|██████████| 189/189 [01:39<00:00,  1.90it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.63it/s]
# 2024-11-01 09:25:17,489 - logging_config - INFO - Epoch [338/800], Train Loss: 0.5364, Val Loss: 26.8252, Val Accuracy: 0.8219
# Training: 100%|██████████| 189/189 [01:40<00:00,  1.89it/s]
# Validation: 100%|██████████| 48/48 [00:17<00:00,  2.67it/s]
# 2024-11-01 09:27:15,606 - logging_config - INFO - Epoch [339/800], Train Loss: 0.5513, Val Loss: 26.9630, Val Accuracy: 0.8149
# Training: 100%|██████████| 189/189 [01:39<00:00,  1.89it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.65it/s]
# 2024-11-01 09:29:13,656 - logging_config - INFO - Epoch [340/800], Train Loss: 0.5504, Val Loss: 26.5543, Val Accuracy: 0.8156
# Training: 100%|██████████| 189/189 [01:39<00:00,  1.89it/s]
# Validation: 100%|██████████| 48/48 [00:17<00:00,  2.67it/s]
# 2024-11-01 09:31:11,599 - logging_config - INFO - Epoch [341/800], Train Loss: 0.6533, Val Loss: 20.2501, Val Accuracy: 0.7726
# Training: 100%|██████████| 189/189 [01:39<00:00,  1.89it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.64it/s]
# 2024-11-01 09:33:09,727 - logging_config - INFO - Epoch [342/800], Train Loss: 0.9306, Val Loss: 12.4660, Val Accuracy: 0.6856
# Training: 100%|██████████| 189/189 [01:42<00:00,  1.84it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.67it/s]
# 2024-11-01 09:35:10,658 - logging_config - INFO - Epoch [343/800], Train Loss: 1.5871, Val Loss: 6.9662, Val Accuracy: 0.6575
# Training: 100%|██████████| 189/189 [01:45<00:00,  1.80it/s]
# Validation: 100%|██████████| 48/48 [00:19<00:00,  2.51it/s]
# 2024-11-01 09:37:15,046 - logging_config - INFO - Epoch [344/800], Train Loss: 1.1365, Val Loss: 9.2209, Val Accuracy: 0.6873
# Training: 100%|██████████| 189/189 [01:44<00:00,  1.81it/s]
# Validation: 100%|██████████| 48/48 [00:18<00:00,  2.57it/s]
# 2024-11-01 09:39:18,273 - logging_config - INFO - Epoch [345/800], Train Loss: 1.0741, Val Loss: 6.8419, Val Accuracy: 0.6753
# Training:  30%|███       | 57/189 [00:38<01:28,  1.49it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [5], line 28
#      25     optimizer = optim.Adam(model.parameters(), lr=0.001)
#      27     # 训练模型
# ---> 28     train_losses, val_losses, val_accuracies = train_model(model, train_loader, test_loader, criterion, optimizer, logger,model_name, epochs)
#      30     results[model_name] = (train_losses, val_losses, val_accuracies)
#      32 save_json(results,r'DL3_results.json')
#
# Cell In [4], line 49, in train_model(model, train_loader, test_loader, criterion, optimizer, logger, model_name, epochs)
#      46 best_model_path = f'DL3_output/{model_name}_best_model_DL3.pth'
#      48 for epoch in range(epochs):
# ---> 49     train_loss = train_epoch(model, train_loader, criterion, optimizer, device)
#      50     val_loss, val_accuracy = validate_epoch(model, test_loader, criterion, device)
#      52     train_losses.append(train_loss)
#
# Cell In [4], line 9, in train_epoch(model, train_loader, criterion, optimizer, device)
#       7 optimizer.zero_grad()
#       8 outputs = model(inputs)
# ----> 9 loss = criterion(outputs, targets)
#      10 loss.backward()
#      11 optimizer.step()
#
# File d:\Anaconda3\envs\PYTORCH\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In [3], line 8, in CustomBCELoss.forward(self, outputs, targets)
#       7 def forward(self, outputs, targets):
# ----> 8     outputs, targets = outputs.to(self.pos_weight.device), targets.to(self.pos_weight.device)
#       9     loss = nn.functional.binary_cross_entropy_with_logits(outputs, targets, pos_weight=self.pos_weight)
#      10     return loss
#
# KeyboardInterrupt:

# %%
# 可视化训练和验证结果
def plot_metrics(epochs, train_losses, val_losses, val_accuracies):
    plt.figure(figsize=(12, 5))

    # 绘制训练和验证损失
    plt.subplot(1, 2, 1)
    plt.plot(range(1, epochs + 1), train_losses, label='Train Loss')
    plt.plot(range(1, epochs + 1), val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Train and Validation Loss')
    plt.legend()

    # 绘制验证准确率
    plt.subplot(1, 2, 2)
    plt.plot(range(1, epochs + 1), val_accuracies, label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Validation Accuracy')
    plt.legend()

    plt.show()

# %%
plot_metrics(epochs, train_losses, val_losses, val_accuracies)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 plot_metrics(epochs, train_losses, val_losses, val_accuracies)
#
# NameError: name 'epochs' is not defined

# %% [markdown]
# 自定义的损失函数 `CustomBCELoss` 使用的是带有权重的二元交叉熵损失 (`binary_cross_entropy_with_logits`) 来处理数据不平衡问题。它的设计和工作原理如下：
#
# ### 数据不平衡问题
# 在分类任务中，尤其是二分类任务中，如果正样本和负样本的数量差异很大（即数据不平衡），标准的损失函数可能会导致模型偏向于预测数量较多的类别，从而忽略数量较少的类别。这种情况会导致模型在测试集上对少数类别的预测效果较差。
#
# ### 如何处理数据不平衡
# `CustomBCELoss` 通过引入 **正样本权重 (pos_weight)** 来处理数据不平衡问题。`pos_weight` 是一个权重参数，用于在计算交叉熵损失时增加正样本的损失贡献，从而平衡正负样本对总损失的影响。
#
# 具体而言：
# - 当样本中的正负类别数量差异较大时，通过增加正样本的权重，使得正样本的错误预测对总损失的影响变大，从而引导模型更加重视正样本的正确分类。
# - 权重的计算方式为：`pos_weight = (总样本数 - 正样本数) / 正样本数`，即负样本和正样本的比例。
#
# ### 实现原理
# 1. **初始化时设置权重**：
#    在 `CustomBCELoss` 的初始化函数中，接受 `pos_weight` 参数：
#    ```python
#    class CustomBCELoss(nn.Module):
#        def __init__(self, pos_weight):
#            super(CustomBCELoss, self).__init__()
#            self.pos_weight = pos_weight
#    ```
#    `pos_weight` 是一个张量，它的值根据正负样本比例计算得到。
#
# 2. **前向传播时使用 `binary_cross_entropy_with_logits`**：
#    在前向传播中使用 PyTorch 提供的 `binary_cross_entropy_with_logits` 函数来计算损失：
#    ```python
#    def forward(self, outputs, targets):
#        outputs, targets = outputs.to(self.pos_weight.device), targets.to(self.pos_weight.device)
#        loss = nn.functional.binary_cross_entropy_with_logits(outputs, targets, pos_weight=self.pos_weight)
#        return loss
#    ```
#    - `binary_cross_entropy_with_logits` 计算二元交叉熵损失，并且可以直接接受 logits（未经过 sigmoid 的原始输出），这样可以提高数值稳定性。
#    - `pos_weight` 参数用于给正样本的损失赋予额外的权重，使得正样本的损失更大，以此来平衡正负样本。
#
# ### 损失函数的作用
# `pos_weight` 的作用是在损失函数中对正样本赋予额外的权重。这意味着：
# - **如果 `pos_weight > 1`**：表示正样本在数据集中相对稀少，因此我们要增加它的损失权重，以使模型更加重视正样本。
# - **如果 `pos_weight = 1`**：表示数据集中的正负样本数量大致相等，此时不会对损失进行任何额外的加权。
# - **如果 `pos_weight < 1`**：这意味着正样本的数量多于负样本（这种情况较为罕见），可以降低正样本的损失权重。
#
# 这种方法在不平衡数据集上训练分类模型时，可以有效地减少类别偏差问题，提高模型对少数类的识别能力。
#
# ### 总结
# 自定义的损失函数 `CustomBCELoss` 通过对正样本的损失加权，解决了样本不平衡的问题，使得模型在训练时对少数类别的样本更加重视，从而提高在不平衡数据集上的性能。权重的引入确保了模型不会因为多数类的压倒性数量而忽略少数类，从而使得分类结果更加平衡。

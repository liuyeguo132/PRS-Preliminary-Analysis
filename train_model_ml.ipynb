# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report, roc_auc_score
from joblib import Parallel, delayed
from tqdm import tqdm
import pickle
import numpy as np 
from ML_Models import ModelSelector
from logging_config import setup_logger

random_state = 3220821

# %% [markdown]
# ### 读取数据

# %%
mm_prs = pd.read_csv(r'mm_prs.csv')
labels = pd.read_csv(r'clean_lables.csv')

X_columns = mm_prs.columns.to_list()[1:]
Y_columns = labels.columns.to_list()[1:]

# %%
mm_prs.shape, labels.shape
# Out:
# ((336978, 38), (336979, 105))

# %% [markdown]
# ### 合并数据

# %%
df = pd.merge(mm_prs,labels,left_on='FID',right_on='eid',how='inner')
df.drop('eid',axis=1,inplace=True)

# %% [markdown]
# ### 检查数据

# %%
df[(df[Y_columns]==0).all(axis=1)]
# Out:
#             FID        HF       AAM       AMD        AD       AST        AF  \
# 0       1000011  0.390474  0.591999  0.553127  0.397860  0.513557  0.504414
# 2       1000044  0.468422  0.444217  0.388766  0.557332  0.456365  0.524752
# 4       1000116  0.351678  0.624132  0.488704  0.486897  0.452750  0.481785
# 7       1000143  0.426496  0.419968  0.453513  0.530163  0.420282  0.461987
# 9       1000168  0.458818  0.280702  0.431210  0.550208  0.509028  0.441621
# ...         ...       ...       ...       ...       ...       ...       ...
# 336959  6023308  0.443033  0.284950  0.484217  0.384919  0.225018  0.574028
# 336966  6023394  0.518329  0.372964  0.522717  0.529828  0.495431  0.448520
# 336969  6023440  0.377258  0.421311  0.439327  0.415556  0.432147  0.375610
# 336971  6023464  0.465263  0.591730  0.420846  0.530429  0.515539  0.518991
# 336972  6023479  0.531587  0.467500  0.611638  0.478736  0.507589  0.455096
#
#               BD       BMI       CRC  ...  Class_I48  Class_I63  Class_I10  \
# 0       0.375549  0.445283  0.545092  ...          0          0          0
# 2       0.537074  0.507530  0.517431  ...          0          0          0
# 4       0.402263  0.388306  0.513450  ...          0          0          0
# 7       0.291205  0.440422  0.477416  ...          0          0          0
# 9       0.477845  0.374281  0.531192  ...          0          0          0
# ...          ...       ...       ...  ...        ...        ...        ...
# 336959  0.380861  0.493368  0.360054  ...          0          0          0
# 336966  0.519743  0.449305  0.571605  ...          0          0          0
# 336969  0.388640  0.495169  0.480763  ...          0          0          0
# 336971  0.520347  0.507308  0.675221  ...          0          0          0
# 336972  0.617440  0.624422  0.612597  ...          0          0          0
#
#         Class_F00  Class_F20  Class_C50  Class_C18  Class_C56  Class_J45  \
# 0               0          0          0          0          0          0
# 2               0          0          0          0          0          0
# 4               0          0          0          0          0          0
# 7               0          0          0          0          0          0
# 9               0          0          0          0          0          0
# ...           ...        ...        ...        ...        ...        ...
# 336959          0          0          0          0          0          0
# 336966          0          0          0          0          0          0
# 336969          0          0          0          0          0          0
# 336971          0          0          0          0          0          0
# 336972          0          0          0          0          0          0
#
#         Class_M05
# 0               0
# 2               0
# 4               0
# 7               0
# 9               0
# ...           ...
# 336959          0
# 336966          0
# 336969          0
# 336971          0
# 336972          0
#
# [105762 rows x 142 columns]

# %% [markdown]
# #### 筛选部分数据集

# %%
import pandas as pd


# 因变量列均为0的样本
df1 = df[(df[Y_columns] == 0).all(axis=1)]

# 因变量列不全为0的样本
df2 = df[~(df[Y_columns] == 0).all(axis=1)]

# 从df1中随机抽取1万条样本形成df3
df3 = df1.sample(n=10000, random_state=random_state)  # 确保抽样可以复现，设置random_state

# 合并df3和df2
df = pd.concat([df2, df3], ignore_index=True)
df.to_csv(r'train_df.csv',index=False)

# %% [markdown]
# ### 读取处理后的数据集

# %%
df = pd.read_csv(r'train_df.csv')

# %%
X = df.iloc[:,1:38]
Y = df.iloc[:,38:]

X_columns = X.columns.to_list()
Y_columns = Y.columns.to_list()

# %% [markdown]
# ### 建立ml模型

# %%
from tools import save_json, load_json

# %%
import os 


logger = setup_logger(r'train_model_ml.log')

def process_column(column, model_name='decision_tree', k_neighbors=2):
 

    if os.path.exists(f'Simple_test/{model_name}_{column}.pkl'):
        return None 
    
    y = Y.loc[:, column]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=random_state)

    # 尝试SMOTE过采样，适应小样本情况
    try:
        smote = SMOTE(random_state=random_state, k_neighbors=k_neighbors)
        X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)
    except ValueError as e:
        logger.error(f"Error in SMOTE for column {column}: {str(e)}")
        # 处理样本量不足的情况，回退到原始数据
        X_train_smote, y_train_smote = X_train, y_train
        logger.info(f"Using original data for training due to insufficient samples in column {column}")

    if len(y_train_smote.unique()) == 1:
        logger.info(f'The y label has only 1 value and is not trained')
        return None 

    logger.info(f'Start training feature column {column}...')
    model = ModelSelector(random_state).get_model(model_name)
    model.fit(X_train_smote, y_train_smote)
    with open(f'Simple_test/{model_name}_{column}.pkl', 'wb') as f:
        pickle.dump(model, f)
    logger.info(f'The training is complete, and the model is saved')

    y_pred = model.predict(X_test)
    return classification_report(y_test, y_pred), roc_auc_score(y_test, model.predict_proba(X_test)[:, 1])

# 依然使用循环处理各列
model_name = 'decision_tree'
results = {}
for column in tqdm(Y_columns):
    results[column] = process_column(column,model_name)

save_json(results,rf'{model_name}_results.json')
# Out:
#   0%|          | 0/104 [00:00<?, ?it/s]2024-10-31 17:38:29,793 - logging_config - INFO - Start training feature column Class_A00...
# 2024-10-31 17:40:22,628 - logging_config - INFO - The training is complete, and the model is saved
#   1%|          | 1/104 [01:53<3:15:28, 113.86s/it]2024-10-31 17:40:23,270 - logging_config - INFO - Start training feature column Class_A01...
# 2024-10-31 17:42:22,082 - logging_config - INFO - The training is complete, and the model is saved
#   2%|▏         | 2/104 [03:53<3:19:09, 117.15s/it]2024-10-31 17:42:22,720 - logging_config - INFO - Start training feature column Class_A02...
# 2024-10-31 17:44:01,593 - logging_config - INFO - The training is complete, and the model is saved
#   3%|▎         | 3/104 [05:32<3:03:39, 109.10s/it]2024-10-31 17:44:02,238 - logging_config - INFO - Start training feature column Class_A03...
# 2024-10-31 17:45:51,703 - logging_config - INFO - The training is complete, and the model is saved
#   4%|▍         | 4/104 [07:22<3:02:29, 109.50s/it]2024-10-31 17:45:52,407 - logging_config - INFO - Start training feature column Class_A04...
# 2024-10-31 17:47:11,280 - logging_config - INFO - The training is complete, and the model is saved
#   5%|▍         | 5/104 [08:42<2:42:53, 98.72s/it] 2024-10-31 17:47:11,958 - logging_config - INFO - Start training feature column Class_A05...
# 2024-10-31 17:48:43,232 - logging_config - INFO - The training is complete, and the model is saved
#   6%|▌         | 6/104 [10:14<2:37:27, 96.40s/it]2024-10-31 17:48:43,847 - logging_config - INFO - Start training feature column Class_A06...
# 2024-10-31 17:50:33,844 - logging_config - INFO - The training is complete, and the model is saved
#   7%|▋         | 7/104 [12:05<2:43:21, 101.05s/it]2024-10-31 17:50:34,455 - logging_config - INFO - Start training feature column Class_A07...
# 2024-10-31 17:52:17,848 - logging_config - INFO - The training is complete, and the model is saved
#   8%|▊         | 8/104 [13:49<2:43:11, 101.99s/it]2024-10-31 17:52:18,559 - logging_config - INFO - Start training feature column Class_A08...
# 2024-10-31 17:53:33,793 - logging_config - INFO - The training is complete, and the model is saved
#   9%|▊         | 9/104 [15:05<2:28:36, 93.86s/it] 2024-10-31 17:53:35,029 - logging_config - INFO - Start training feature column Class_A09...
# 2024-10-31 17:54:43,195 - logging_config - INFO - The training is complete, and the model is saved
#  10%|▉         | 10/104 [16:14<2:15:14, 86.32s/it]2024-10-31 17:54:43,922 - logging_config - INFO - Start training feature column Class_A15...
# 2024-10-31 17:56:10,567 - logging_config - INFO - The training is complete, and the model is saved
#  11%|█         | 11/104 [17:41<2:14:16, 86.63s/it]2024-10-31 17:56:11,223 - logging_config - INFO - Start training feature column Class_A16...
# 2024-10-31 17:57:58,031 - logging_config - INFO - The training is complete, and the model is saved
#  12%|█▏        | 12/104 [19:29<2:22:32, 92.96s/it]2024-10-31 17:57:58,638 - logging_config - INFO - Start training feature column Class_A17...
# 2024-10-31 17:58:44,323 - logging_config - INFO - The training is complete, and the model is saved
#  12%|█▎        | 13/104 [20:15<1:59:32, 78.82s/it]2024-10-31 17:58:44,935 - logging_config - INFO - Start training feature column Class_A18...
# 2024-10-31 18:00:55,578 - logging_config - INFO - The training is complete, and the model is saved
#  13%|█▎        | 14/104 [22:26<2:21:59, 94.66s/it]2024-10-31 18:00:56,181 - logging_config - INFO - Start training feature column Class_A19...
# 2024-10-31 18:02:21,522 - logging_config - INFO - The training is complete, and the model is saved
#  14%|█▍        | 15/104 [23:52<2:16:30, 92.03s/it]2024-10-31 18:02:23,104 - logging_config - INFO - Start training feature column Class_D50...
# 2024-10-31 18:03:27,121 - logging_config - INFO - The training is complete, and the model is saved
#  15%|█▌        | 16/104 [24:58<2:03:20, 84.10s/it]2024-10-31 18:03:27,859 - logging_config - INFO - Start training feature column Class_D51...
# 2024-10-31 18:04:45,124 - logging_config - INFO - The training is complete, and the model is saved
#  16%|█▋        | 17/104 [26:16<1:59:15, 82.25s/it]2024-10-31 18:04:45,789 - logging_config - INFO - Start training feature column Class_D52...
# 2024-10-31 18:06:18,511 - logging_config - INFO - The training is complete, and the model is saved
#  17%|█▋        | 18/104 [27:49<2:02:41, 85.59s/it]2024-10-31 18:06:19,130 - logging_config - INFO - Start training feature column Class_D53...
# 2024-10-31 18:08:07,423 - logging_config - INFO - The training is complete, and the model is saved
#  18%|█▊        | 19/104 [29:38<2:11:10, 92.59s/it]2024-10-31 18:08:08,066 - logging_config - INFO - Start training feature column Class_D55...
# 2024-10-31 18:08:36,973 - logging_config - INFO - The training is complete, and the model is saved
#  19%|█▉        | 20/104 [30:08<1:43:07, 73.66s/it]2024-10-31 18:08:37,557 - logging_config - INFO - Start training feature column Class_D56...
# 2024-10-31 18:10:36,766 - logging_config - INFO - The training is complete, and the model is saved
#  20%|██        | 21/104 [32:07<2:01:03, 87.51s/it]2024-10-31 18:10:37,382 - logging_config - INFO - Start training feature column Class_D57...
# 2024-10-31 18:12:47,664 - logging_config - INFO - The training is complete, and the model is saved
#  21%|██        | 22/104 [34:18<2:17:23, 100.53s/it]2024-10-31 18:12:48,271 - logging_config - INFO - Start training feature column Class_D58...
# 2024-10-31 18:14:44,084 - logging_config - INFO - The training is complete, and the model is saved
#  22%|██▏       | 23/104 [36:15<2:22:09, 105.30s/it]2024-10-31 18:14:44,688 - logging_config - INFO - Start training feature column Class_D59...
# 2024-10-31 18:16:28,850 - logging_config - INFO - The training is complete, and the model is saved
#  23%|██▎       | 24/104 [38:00<2:20:11, 105.14s/it]2024-10-31 18:16:29,472 - logging_config - INFO - Start training feature column Class_D60...
# 2024-10-31 18:17:21,537 - logging_config - INFO - The training is complete, and the model is saved
#  24%|██▍       | 25/104 [38:52<1:57:42, 89.40s/it] 2024-10-31 18:17:22,173 - logging_config - INFO - Start training feature column Class_D61...
# 2024-10-31 18:18:48,754 - logging_config - INFO - The training is complete, and the model is saved
#  25%|██▌       | 26/104 [40:20<1:55:22, 88.75s/it]2024-10-31 18:18:49,377 - logging_config - INFO - Start training feature column Class_D62...
# 2024-10-31 18:20:24,119 - logging_config - INFO - The training is complete, and the model is saved
#  26%|██▌       | 27/104 [41:55<1:56:26, 90.74s/it]2024-10-31 18:20:24,784 - logging_config - INFO - Start training feature column Class_D63...
# 2024-10-31 18:21:54,975 - logging_config - INFO - The training is complete, and the model is saved
#  27%|██▋       | 28/104 [43:26<1:54:58, 90.78s/it]2024-10-31 18:21:56,672 - logging_config - INFO - Start training feature column Class_D64...
# 2024-10-31 18:23:00,200 - logging_config - INFO - The training is complete, and the model is saved
#  28%|██▊       | 29/104 [44:31<1:43:54, 83.13s/it]2024-10-31 18:23:00,913 - logging_config - INFO - Start training feature column Class_D65...
# 2024-10-31 18:24:46,239 - logging_config - INFO - The training is complete, and the model is saved
#  29%|██▉       | 30/104 [46:17<1:50:58, 89.98s/it]2024-10-31 18:24:46,856 - logging_config - INFO - Start training feature column Class_D66...
# 2024-10-31 18:26:56,421 - logging_config - INFO - The training is complete, and the model is saved
#  30%|██▉       | 31/104 [48:27<2:04:08, 102.03s/it]2024-10-31 18:26:57,014 - logging_config - INFO - Start training feature column Class_E01...
# 2024-10-31 18:28:40,755 - logging_config - INFO - The training is complete, and the model is saved
#  31%|███       | 32/104 [50:11<2:03:16, 102.73s/it]2024-10-31 18:28:41,372 - logging_config - INFO - Start training feature column Class_E02...
# 2024-10-31 18:30:22,271 - logging_config - INFO - The training is complete, and the model is saved
#  32%|███▏      | 33/104 [51:53<2:01:07, 102.36s/it]2024-10-31 18:30:24,225 - logging_config - INFO - Start training feature column Class_E03...
# 2024-10-31 18:31:23,600 - logging_config - INFO - The training is complete, and the model is saved
#  33%|███▎      | 34/104 [52:54<1:45:05, 90.08s/it] 2024-10-31 18:31:24,396 - logging_config - INFO - Start training feature column Class_E04...
# 2024-10-31 18:32:41,400 - logging_config - INFO - The training is complete, and the model is saved
#  34%|███▎      | 35/104 [54:12<1:39:20, 86.38s/it]2024-10-31 18:32:42,144 - logging_config - INFO - Start training feature column Class_E05...
# 2024-10-31 18:33:54,064 - logging_config - INFO - The training is complete, and the model is saved
#  35%|███▍      | 36/104 [55:25<1:33:14, 82.27s/it]2024-10-31 18:33:54,742 - logging_config - INFO - Start training feature column Class_E06...
# 2024-10-31 18:35:27,180 - logging_config - INFO - The training is complete, and the model is saved
#  36%|███▌      | 37/104 [56:58<1:35:29, 85.51s/it]2024-10-31 18:35:27,837 - logging_config - INFO - Start training feature column Class_E07...
# 2024-10-31 18:36:52,426 - logging_config - INFO - The training is complete, and the model is saved
#  37%|███▋      | 38/104 [58:23<1:33:58, 85.43s/it]2024-10-31 18:36:53,147 - logging_config - INFO - Start training feature column Class_E10...
# 2024-10-31 18:38:07,674 - logging_config - INFO - The training is complete, and the model is saved
#  38%|███▊      | 39/104 [59:38<1:29:14, 82.38s/it]2024-10-31 18:38:10,043 - logging_config - INFO - Start training feature column Class_E11...
# 2024-10-31 18:39:01,892 - logging_config - INFO - The training is complete, and the model is saved
#  38%|███▊      | 40/104 [1:00:33<1:18:52, 73.95s/it]2024-10-31 18:39:02,261 - logging_config - ERROR - Error in SMOTE for column Class_E12: Expected n_neighbors <= n_samples,  but n_samples = 2, n_neighbors = 3
# 2024-10-31 18:39:02,262 - logging_config - INFO - Using original data for training due to insufficient samples in column Class_E12
# 2024-10-31 18:39:02,267 - logging_config - INFO - Start training feature column Class_E12...
# 2024-10-31 18:39:04,765 - logging_config - INFO - The training is complete, and the model is saved
# d:\Anaconda3\envs\PYTORCH\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\Anaconda3\envs\PYTORCH\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\Anaconda3\envs\PYTORCH\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  39%|███▉      | 41/104 [1:00:35<55:13, 52.60s/it]  2024-10-31 18:39:05,373 - logging_config - INFO - Start training feature column Class_E13...
# 2024-10-31 18:40:58,182 - logging_config - INFO - The training is complete, and the model is saved
#  40%|████      | 42/104 [1:02:29<1:13:12, 70.85s/it]2024-10-31 18:40:59,496 - logging_config - INFO - Start training feature column Class_E14...
# 2024-10-31 18:42:02,508 - logging_config - INFO - The training is complete, and the model is saved
#  41%|████▏     | 43/104 [1:03:33<1:10:03, 68.91s/it]2024-10-31 18:42:03,210 - logging_config - INFO - Start training feature column Class_E15...
# 2024-10-31 18:44:10,482 - logging_config - INFO - The training is complete, and the model is saved
#  42%|████▏     | 44/104 [1:05:41<1:26:36, 86.60s/it]2024-10-31 18:44:11,165 - logging_config - INFO - Start training feature column Class_E16...
# 2024-10-31 18:45:23,887 - logging_config - INFO - The training is complete, and the model is saved
#  43%|████▎     | 45/104 [1:06:55<1:21:16, 82.66s/it]2024-10-31 18:45:24,519 - logging_config - INFO - Start training feature column Class_E20...
# 2024-10-31 18:47:11,314 - logging_config - INFO - The training is complete, and the model is saved
#  44%|████▍     | 46/104 [1:08:42<1:27:04, 90.08s/it]2024-10-31 18:47:11,970 - logging_config - INFO - Start training feature column Class_F01...
# 2024-10-31 18:48:32,206 - logging_config - INFO - The training is complete, and the model is saved
#  45%|████▌     | 47/104 [1:10:03<1:22:57, 87.33s/it]2024-10-31 18:48:32,850 - logging_config - INFO - Start training feature column Class_F02...
# 2024-10-31 18:50:05,291 - logging_config - INFO - The training is complete, and the model is saved
#  46%|████▌     | 48/104 [1:11:36<1:23:07, 89.06s/it]2024-10-31 18:50:06,014 - logging_config - INFO - Start training feature column Class_F03...
# 2024-10-31 18:51:18,562 - logging_config - INFO - The training is complete, and the model is saved
#  47%|████▋     | 49/104 [1:12:49<1:17:17, 84.32s/it]2024-10-31 18:51:19,220 - logging_config - INFO - Start training feature column Class_F04...
# 2024-10-31 18:52:58,242 - logging_config - INFO - The training is complete, and the model is saved
#  48%|████▊     | 50/104 [1:14:29<1:20:01, 88.92s/it]2024-10-31 18:52:58,928 - logging_config - INFO - Start training feature column Class_F05...
# 2024-10-31 18:54:09,629 - logging_config - INFO - The training is complete, and the model is saved
#  49%|████▉     | 51/104 [1:15:40<1:13:54, 83.68s/it]2024-10-31 18:54:10,343 - logging_config - INFO - Start training feature column Class_F06...
# 2024-10-31 18:55:41,335 - logging_config - INFO - The training is complete, and the model is saved
#  50%|█████     | 52/104 [1:17:12<1:14:35, 86.07s/it]2024-10-31 18:55:41,962 - logging_config - INFO - Start training feature column Class_F07...
# 2024-10-31 18:57:41,547 - logging_config - INFO - The training is complete, and the model is saved
#  51%|█████     | 53/104 [1:19:12<1:21:51, 96.31s/it]2024-10-31 18:57:42,146 - logging_config - INFO - Start training feature column Class_F09...
# 2024-10-31 18:59:17,544 - logging_config - INFO - The training is complete, and the model is saved
#  52%|█████▏    | 54/104 [1:20:48<1:20:10, 96.22s/it]2024-10-31 18:59:18,317 - logging_config - INFO - Start training feature column Class_F10...
# 2024-10-31 19:00:30,349 - logging_config - INFO - The training is complete, and the model is saved
#  53%|█████▎    | 55/104 [1:22:01<1:12:51, 89.21s/it]2024-10-31 19:00:31,020 - logging_config - INFO - Start training feature column Class_F11...
# 2024-10-31 19:02:22,636 - logging_config - INFO - The training is complete, and the model is saved
#  54%|█████▍    | 56/104 [1:23:53<1:16:53, 96.12s/it]2024-10-31 19:02:23,251 - logging_config - INFO - Start training feature column Class_F12...
# 2024-10-31 19:04:00,426 - logging_config - INFO - The training is complete, and the model is saved
#  55%|█████▍    | 57/104 [1:25:31<1:15:41, 96.62s/it]2024-10-31 19:04:01,046 - logging_config - INFO - Start training feature column Class_F13...
# 2024-10-31 19:06:03,840 - logging_config - INFO - The training is complete, and the model is saved
#  56%|█████▌    | 58/104 [1:27:35<1:20:14, 104.66s/it]2024-10-31 19:06:04,454 - logging_config - INFO - Start training feature column Class_F14...
# 2024-10-31 19:08:08,566 - logging_config - INFO - The training is complete, and the model is saved
#  57%|█████▋    | 59/104 [1:29:39<1:23:00, 110.68s/it]2024-10-31 19:08:09,180 - logging_config - INFO - Start training feature column Class_F15...
# 2024-10-31 19:10:11,231 - logging_config - INFO - The training is complete, and the model is saved
#  58%|█████▊    | 60/104 [1:31:42<1:23:47, 114.27s/it]2024-10-31 19:10:11,814 - logging_config - INFO - Start training feature column Class_F16...
# 2024-10-31 19:12:13,266 - logging_config - INFO - The training is complete, and the model is saved
#  59%|█████▊    | 61/104 [1:33:44<1:23:33, 116.60s/it]2024-10-31 19:12:15,472 - logging_config - INFO - Start training feature column Class_F17...
# 2024-10-31 19:13:13,310 - logging_config - INFO - The training is complete, and the model is saved
#  60%|█████▉    | 62/104 [1:34:44<1:09:45, 99.66s/it] 2024-10-31 19:13:14,007 - logging_config - INFO - Start training feature column Class_G00...
# 2024-10-31 19:14:47,111 - logging_config - INFO - The training is complete, and the model is saved
#  61%|██████    | 63/104 [1:36:18<1:06:53, 97.88s/it]2024-10-31 19:14:47,720 - logging_config - INFO - Start training feature column Class_G01...
# 2024-10-31 19:17:08,416 - logging_config - INFO - The training is complete, and the model is saved
#  62%|██████▏   | 64/104 [1:38:39<1:13:56, 110.90s/it]2024-10-31 19:17:09,019 - logging_config - INFO - Start training feature column Class_G02...
# 2024-10-31 19:18:53,039 - logging_config - INFO - The training is complete, and the model is saved
#  62%|██████▎   | 65/104 [1:40:24<1:10:51, 109.02s/it]2024-10-31 19:18:53,667 - logging_config - INFO - Start training feature column Class_G03...
# 2024-10-31 19:20:16,234 - logging_config - INFO - The training is complete, and the model is saved
#  63%|██████▎   | 66/104 [1:41:47<1:04:08, 101.28s/it]2024-10-31 19:20:16,884 - logging_config - INFO - Start training feature column Class_G04...
# 2024-10-31 19:21:46,634 - logging_config - INFO - The training is complete, and the model is saved
#  64%|██████▍   | 67/104 [1:43:17<1:00:26, 98.01s/it] 2024-10-31 19:21:47,258 - logging_config - INFO - Start training feature column Class_G05...
# 2024-10-31 19:23:29,323 - logging_config - INFO - The training is complete, and the model is saved
#  65%|██████▌   | 68/104 [1:45:00<59:38, 99.41s/it]  2024-10-31 19:23:29,968 - logging_config - INFO - Start training feature column Class_G06...
# 2024-10-31 19:25:18,798 - logging_config - INFO - The training is complete, and the model is saved
#  66%|██████▋   | 69/104 [1:46:50<59:45, 102.43s/it]2024-10-31 19:25:19,081 - logging_config - ERROR - Error in SMOTE for column Class_G07: Expected n_neighbors <= n_samples,  but n_samples = 2, n_neighbors = 3
# 2024-10-31 19:25:19,081 - logging_config - INFO - Using original data for training due to insufficient samples in column Class_G07
# 2024-10-31 19:25:19,086 - logging_config - INFO - Start training feature column Class_G07...
# 2024-10-31 19:25:21,498 - logging_config - INFO - The training is complete, and the model is saved
#  67%|██████▋   | 70/104 [1:46:52<41:05, 72.50s/it] 2024-10-31 19:25:22,082 - logging_config - INFO - Start training feature column Class_G08...
# 2024-10-31 19:27:23,715 - logging_config - INFO - The training is complete, and the model is saved
#  68%|██████▊   | 71/104 [1:48:54<48:05, 87.42s/it]2024-10-31 19:27:24,312 - logging_config - INFO - Start training feature column Class_G09...
# 2024-10-31 19:29:21,384 - logging_config - INFO - The training is complete, and the model is saved
#  69%|██████▉   | 72/104 [1:50:52<51:27, 96.49s/it]2024-10-31 19:29:21,975 - logging_config - INFO - Start training feature column Class_G10...
# 2024-10-31 19:31:37,491 - logging_config - INFO - The training is complete, and the model is saved
#  70%|███████   | 73/104 [1:53:08<55:59, 108.38s/it]2024-10-31 19:31:38,089 - logging_config - INFO - Start training feature column Class_G11...
# 2024-10-31 19:33:26,633 - logging_config - INFO - The training is complete, and the model is saved
#  71%|███████   | 74/104 [1:54:57<54:18, 108.61s/it]2024-10-31 19:33:27,260 - logging_config - INFO - Start training feature column Class_G12...
# 2024-10-31 19:35:08,003 - logging_config - INFO - The training is complete, and the model is saved
#  72%|███████▏  | 75/104 [1:56:39<51:26, 106.44s/it]2024-10-31 19:35:08,609 - logging_config - INFO - Start training feature column Class_G13...
# 2024-10-31 19:37:17,522 - logging_config - INFO - The training is complete, and the model is saved
#  73%|███████▎  | 76/104 [1:58:48<52:54, 113.36s/it]2024-10-31 19:37:18,125 - logging_config - INFO - Start training feature column Class_G14...
# 2024-10-31 19:39:07,376 - logging_config - INFO - The training is complete, and the model is saved
#  74%|███████▍  | 77/104 [2:00:38<50:32, 112.31s/it]2024-10-31 19:39:08,064 - logging_config - INFO - Start training feature column Class_G20...
# 2024-10-31 19:40:24,163 - logging_config - INFO - The training is complete, and the model is saved
#  75%|███████▌  | 78/104 [2:01:55<44:03, 101.67s/it]2024-10-31 19:40:24,828 - logging_config - INFO - Start training feature column Class_I00...
# 2024-10-31 19:41:43,194 - logging_config - INFO - The training is complete, and the model is saved
#  76%|███████▌  | 79/104 [2:03:14<39:31, 94.87s/it] 2024-10-31 19:41:43,818 - logging_config - INFO - Start training feature column Class_I01...
# 2024-10-31 19:43:27,287 - logging_config - INFO - The training is complete, and the model is saved
#  77%|███████▋  | 80/104 [2:04:58<39:03, 97.63s/it]2024-10-31 19:43:27,901 - logging_config - INFO - Start training feature column Class_I02...
# 2024-10-31 19:45:23,302 - logging_config - INFO - The training is complete, and the model is saved
#  78%|███████▊  | 81/104 [2:06:54<39:32, 103.14s/it]2024-10-31 19:45:23,904 - logging_config - INFO - Start training feature column Class_I05...
# 2024-10-31 19:46:59,984 - logging_config - INFO - The training is complete, and the model is saved
#  79%|███████▉  | 82/104 [2:08:31<37:06, 101.21s/it]2024-10-31 19:47:00,600 - logging_config - INFO - Start training feature column Class_I06...
# 2024-10-31 19:48:56,104 - logging_config - INFO - The training is complete, and the model is saved
#  80%|███████▉  | 83/104 [2:10:27<36:59, 105.68s/it]2024-10-31 19:48:56,741 - logging_config - INFO - Start training feature column Class_I07...
# 2024-10-31 19:50:16,626 - logging_config - INFO - The training is complete, and the model is saved
#  81%|████████  | 84/104 [2:11:47<32:42, 98.14s/it] 2024-10-31 19:50:17,365 - logging_config - INFO - Start training feature column Class_I08...
# 2024-10-31 19:51:29,343 - logging_config - INFO - The training is complete, and the model is saved
#  82%|████████▏ | 85/104 [2:13:00<28:39, 90.52s/it]2024-10-31 19:51:30,010 - logging_config - INFO - Start training feature column Class_I09...
# 2024-10-31 19:53:21,958 - logging_config - INFO - The training is complete, and the model is saved
#  83%|████████▎ | 86/104 [2:14:53<29:08, 97.13s/it]2024-10-31 19:53:22,576 - logging_config - INFO - Start training feature column Class_I11...
# 2024-10-31 19:54:48,559 - logging_config - INFO - The training is complete, and the model is saved
#  84%|████████▎ | 87/104 [2:16:19<26:37, 93.98s/it]2024-10-31 19:54:49,235 - logging_config - INFO - Start training feature column Class_I12...
# 2024-10-31 19:56:16,706 - logging_config - INFO - The training is complete, and the model is saved
#  85%|████████▍ | 88/104 [2:17:47<24:35, 92.23s/it]2024-10-31 19:56:17,337 - logging_config - INFO - Start training feature column Class_I13...
# 2024-10-31 19:58:20,203 - logging_config - INFO - The training is complete, and the model is saved
#  86%|████████▌ | 89/104 [2:19:51<25:24, 101.60s/it]2024-10-31 19:58:22,021 - logging_config - INFO - Start training feature column Class_I20...
# 2024-10-31 19:59:16,330 - logging_config - INFO - The training is complete, and the model is saved
#  87%|████████▋ | 90/104 [2:20:47<20:31, 87.99s/it] 2024-10-31 19:59:17,753 - logging_config - INFO - Start training feature column Class_I21...
# 2024-10-31 20:00:17,413 - logging_config - INFO - The training is complete, and the model is saved
#  88%|████████▊ | 91/104 [2:21:48<17:18, 79.91s/it]2024-10-31 20:00:18,106 - logging_config - INFO - Start training feature column Class_I22...
# 2024-10-31 20:01:54,154 - logging_config - INFO - The training is complete, and the model is saved
#  88%|████████▊ | 92/104 [2:23:25<16:59, 84.94s/it]2024-10-31 20:01:55,325 - logging_config - INFO - Start training feature column Class_I50...
# 2024-10-31 20:02:54,996 - logging_config - INFO - The training is complete, and the model is saved
#  89%|████████▉ | 93/104 [2:24:26<14:15, 77.73s/it]2024-10-31 20:02:58,603 - logging_config - INFO - Start training feature column Class_I25...
# 2024-10-31 20:03:48,720 - logging_config - INFO - The training is complete, and the model is saved
#  90%|█████████ | 94/104 [2:25:20<11:45, 70.54s/it]2024-10-31 20:03:51,102 - logging_config - INFO - Start training feature column Class_I48...
# 2024-10-31 20:04:48,331 - logging_config - INFO - The training is complete, and the model is saved
#  91%|█████████▏| 95/104 [2:26:19<10:05, 67.25s/it]2024-10-31 20:04:49,319 - logging_config - INFO - Start training feature column Class_I63...
# 2024-10-31 20:05:54,680 - logging_config - INFO - The training is complete, and the model is saved
#  92%|█████████▏| 96/104 [2:27:25<08:55, 66.98s/it]2024-10-31 20:06:14,577 - logging_config - INFO - Start training feature column Class_I10...
# 2024-10-31 20:06:40,020 - logging_config - INFO - The training is complete, and the model is saved
#  93%|█████████▎| 97/104 [2:28:11<07:03, 60.50s/it]2024-10-31 20:06:40,813 - logging_config - INFO - Start training feature column Class_F00...
# 2024-10-31 20:07:58,818 - logging_config - INFO - The training is complete, and the model is saved
#  94%|█████████▍| 98/104 [2:29:30<06:35, 65.97s/it]2024-10-31 20:07:59,476 - logging_config - INFO - Start training feature column Class_F20...
# 2024-10-31 20:09:30,238 - logging_config - INFO - The training is complete, and the model is saved
#  95%|█████████▌| 99/104 [2:31:01<06:07, 73.60s/it]2024-10-31 20:09:31,174 - logging_config - INFO - Start training feature column Class_C50...
# 2024-10-31 20:10:33,914 - logging_config - INFO - The training is complete, and the model is saved
#  96%|█████████▌| 100/104 [2:32:05<04:42, 70.63s/it]2024-10-31 20:10:34,677 - logging_config - INFO - Start training feature column Class_C18...
# 2024-10-31 20:11:41,619 - logging_config - INFO - The training is complete, and the model is saved
#  97%|█████████▋| 101/104 [2:33:12<03:29, 69.75s/it]2024-10-31 20:11:42,309 - logging_config - INFO - Start training feature column Class_C56...
# 2024-10-31 20:13:08,185 - logging_config - INFO - The training is complete, and the model is saved
#  98%|█████████▊| 102/104 [2:34:39<02:29, 74.79s/it]2024-10-31 20:13:13,153 - logging_config - INFO - Start training feature column Class_J45...
# 2024-10-31 20:13:58,217 - logging_config - INFO - The training is complete, and the model is saved
#  99%|█████████▉| 103/104 [2:35:29<01:07, 67.38s/it]2024-10-31 20:13:59,065 - logging_config - INFO - Start training feature column Class_M05...
# 2024-10-31 20:15:04,078 - logging_config - INFO - The training is complete, and the model is saved
# 100%|██████████| 104/104 [2:36:35<00:00, 90.34s/it]

# %% [markdown]
# #### 查看result结果

# %%
results = load_json(rf'{model_name}_results.json')

# %%
print(results['Class_A00'][0])
print(results['Class_A00'][1])
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72361
#            1       0.00      0.00      0.00         4
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
# 0.4998618040104476

# %%
# 输出结果
for column in results.keys():
    print(f"结果对于标签列 {column}:")
    print(" 分类报告:\n", results[column][0])
    print(" AUC-ROC:",  results[column][1],end='\n\n')
# Out:
# 结果对于标签列 Class_A00:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72361
#            1       0.00      0.00      0.00         4
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.4998618040104476
#
# 结果对于标签列 Class_A01:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72348
#            1       0.00      0.00      0.00        17
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.49912229778293804
#
# 结果对于标签列 Class_A02:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     72194
#            1       0.01      0.03      0.01       171
#
#     accuracy                           0.98     72365
#    macro avg       0.50      0.51      0.50     72365
# weighted avg       1.00      0.98      0.99     72365
#
#  AUC-ROC: 0.5078533927508838
#
# 结果对于标签列 Class_A03:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72321
#            1       0.00      0.00      0.00        44
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.49841678074141677
#
# 结果对于标签列 Class_A04:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.98      0.89      0.93     70656
#            1       0.03      0.12      0.04      1709
#
#     accuracy                           0.87     72365
#    macro avg       0.50      0.51      0.49     72365
# weighted avg       0.95      0.87      0.91     72365
#
#  AUC-ROC: 0.5053154006774133
#
# 结果对于标签列 Class_A05:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     72279
#            1       0.00      0.00      0.00        86
#
#     accuracy                           0.99     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      0.99      1.00     72365
#
#  AUC-ROC: 0.49701849776560275
#
# 结果对于标签列 Class_A06:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72346
#            1       0.00      0.00      0.00        19
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.49914300721532634
#
# 结果对于标签列 Class_A07:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     72239
#            1       0.00      0.01      0.00       126
#
#     accuracy                           0.99     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      0.99      0.99     72365
#
#  AUC-ROC: 0.4994139273579742
#
# 结果对于标签列 Class_A08:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.98      0.92      0.95     71203
#            1       0.02      0.08      0.03      1162
#
#     accuracy                           0.90     72365
#    macro avg       0.50      0.50      0.49     72365
# weighted avg       0.97      0.90      0.93     72365
#
#  AUC-ROC: 0.5001249669347365
#
# 结果对于标签列 Class_A09:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.92      0.77      0.84     66894
#            1       0.08      0.23      0.11      5471
#
#     accuracy                           0.73     72365
#    macro avg       0.50      0.50      0.48     72365
# weighted avg       0.86      0.73      0.79     72365
#
#  AUC-ROC: 0.5011941526697926
#
# 结果对于标签列 Class_A15:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.99      0.96      0.98     71834
#            1       0.01      0.04      0.01       531
#
#     accuracy                           0.95     72365
#    macro avg       0.50      0.50      0.49     72365
# weighted avg       0.99      0.95      0.97     72365
#
#  AUC-ROC: 0.49966514920070737
#
# 结果对于标签列 Class_A16:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     72244
#            1       0.00      0.00      0.00       121
#
#     accuracy                           0.99     72365
#    macro avg       0.50      0.49      0.50     72365
# weighted avg       1.00      0.99      0.99     72365
#
#  AUC-ROC: 0.49474004761641105
#
# 结果对于标签列 Class_A17:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72362
#            1       0.00      0.00      0.00         3
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.4998825350321992
#
# 结果对于标签列 Class_A18:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72332
#            1       0.00      0.00      0.00        33
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.4992050544710502
#
# 结果对于标签列 Class_A19:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72362
#            1       0.00      0.00      0.00         3
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.4999032641441641
#
# 结果对于标签列 Class_D50:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.91      0.75      0.82     65825
#            1       0.09      0.24      0.13      6540
#
#     accuracy                           0.71     72365
#    macro avg       0.50      0.50      0.48     72365
# weighted avg       0.83      0.71      0.76     72365
#
#  AUC-ROC: 0.4968209714154968
#
# 结果对于标签列 Class_D51:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.99      0.94      0.97     71586
#            1       0.01      0.06      0.02       779
#
#     accuracy                           0.94     72365
#    macro avg       0.50      0.50      0.49     72365
# weighted avg       0.98      0.94      0.96     72365
#
#  AUC-ROC: 0.5025218103510389
#
# 结果对于标签列 Class_D52:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     72145
#            1       0.00      0.01      0.00       220
#
#     accuracy                           0.98     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       0.99      0.98      0.99     72365
#
#  AUC-ROC: 0.4953348370390438
#
# 结果对于标签列 Class_D53:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72301
#            1       0.00      0.00      0.00        64
#
#     accuracy                           0.99     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      0.99      1.00     72365
#
#  AUC-ROC: 0.4978838466964496
#
# 结果对于标签列 Class_D55:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72361
#            1       0.00      0.00      0.00         4
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.4999378118047014
#
# 结果对于标签列 Class_D56:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72328
#            1       0.00      0.00      0.00        37
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.498264849021126
#
# 结果对于标签列 Class_D57:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72357
#            1       0.00      0.00      0.00         8
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.4996061196567022
#
# 结果对于标签列 Class_D58:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72302
#            1       0.00      0.00      0.00        63
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.4984094492545158
#
# 结果对于标签列 Class_D59:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     72290
#            1       0.00      0.01      0.00        75
#
#     accuracy                           0.99     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      0.99      1.00     72365
#
#  AUC-ROC: 0.503339788813575
#
# 结果对于标签列 Class_D60:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72360
#            1       0.00      0.00      0.00         5
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.499965450525152
#
# 结果对于标签列 Class_D61:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98     72022
#            1       0.01      0.05      0.01       343
#
#     accuracy                           0.97     72365
#    macro avg       0.50      0.51      0.50     72365
# weighted avg       0.99      0.97      0.98     72365
#
#  AUC-ROC: 0.5115699381781061
#
# 结果对于标签列 Class_D62:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     72279
#            1       0.00      0.01      0.00        86
#
#     accuracy                           0.99     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      0.99      0.99     72365
#
#  AUC-ROC: 0.501884734766475
#
# 结果对于标签列 Class_D63:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98     71947
#            1       0.01      0.04      0.01       418
#
#     accuracy                           0.96     72365
#    macro avg       0.50      0.51      0.50     72365
# weighted avg       0.99      0.96      0.98     72365
#
#  AUC-ROC: 0.5059571363104007
#
# 结果对于标签列 Class_D64:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.91      0.74      0.82     65497
#            1       0.10      0.26      0.14      6868
#
#     accuracy                           0.70     72365
#    macro avg       0.50      0.50      0.48     72365
# weighted avg       0.83      0.70      0.75     72365
#
#  AUC-ROC: 0.5004815282767489
#
# 结果对于标签列 Class_D65:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72341
#            1       0.00      0.00      0.00        24
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.49923280021011596
#
# 结果对于标签列 Class_D66:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72336
#            1       0.00      0.00      0.00        29
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.49897008405220084
#
# 结果对于标签列 Class_E01:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72351
#            1       0.00      0.00      0.00        14
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.49898411908612184
#
# 结果对于标签列 Class_E02:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72311
#            1       0.00      0.00      0.00        54
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.4982506119400921
#
# 结果对于标签列 Class_E03:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.89      0.73      0.80     64350
#            1       0.12      0.28      0.17      8015
#
#     accuracy                           0.68     72365
#    macro avg       0.50      0.51      0.48     72365
# weighted avg       0.81      0.68      0.73     72365
#
#  AUC-ROC: 0.5080377313128405
#
# 结果对于标签列 Class_E04:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.98      0.92      0.95     71228
#            1       0.02      0.08      0.03      1137
#
#     accuracy                           0.91     72365
#    macro avg       0.50      0.50      0.49     72365
# weighted avg       0.97      0.91      0.94     72365
#
#  AUC-ROC: 0.503500607189597
#
# 结果对于标签列 Class_E05:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.98      0.89      0.93     70631
#            1       0.03      0.13      0.05      1734
#
#     accuracy                           0.87     72365
#    macro avg       0.50      0.51      0.49     72365
# weighted avg       0.95      0.87      0.91     72365
#
#  AUC-ROC: 0.5087515199329322
#
# 结果对于标签列 Class_E06:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     72044
#            1       0.00      0.02      0.01       321
#
#     accuracy                           0.97     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       0.99      0.97      0.98     72365
#
#  AUC-ROC: 0.49867478873675497
#
# 结果对于标签列 Class_E07:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97     71719
#            1       0.01      0.04      0.01       646
#
#     accuracy                           0.94     72365
#    macro avg       0.50      0.49      0.49     72365
# weighted avg       0.98      0.94      0.96     72365
#
#  AUC-ROC: 0.4934777593684882
#
# 结果对于标签列 Class_E10:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     71356
#            1       0.02      0.10      0.03      1009
#
#     accuracy                           0.92     72365
#    macro avg       0.50      0.52      0.50     72365
# weighted avg       0.97      0.92      0.95     72365
#
#  AUC-ROC: 0.517343397899203
#
# 结果对于标签列 Class_E11:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.89      0.73      0.80     63701
#            1       0.15      0.34      0.21      8664
#
#     accuracy                           0.68     72365
#    macro avg       0.52      0.54      0.50     72365
# weighted avg       0.80      0.68      0.73     72365
#
#  AUC-ROC: 0.5364721022222023
#
# 结果对于标签列 Class_E12:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72361
#            1       0.00      0.00      0.00         4
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.5
#
# 结果对于标签列 Class_E13:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     72245
#            1       0.01      0.04      0.01       120
#
#     accuracy                           0.99     72365
#    macro avg       0.50      0.52      0.50     72365
# weighted avg       1.00      0.99      0.99     72365
#
#  AUC-ROC: 0.5166185087780009
#
# 结果对于标签列 Class_E14:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.94      0.80      0.86     67583
#            1       0.09      0.28      0.13      4782
#
#     accuracy                           0.76     72365
#    macro avg       0.51      0.54      0.50     72365
# weighted avg       0.88      0.76      0.81     72365
#
#  AUC-ROC: 0.535570216916785
#
# 结果对于标签列 Class_E15:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72356
#            1       0.00      0.00      0.00         9
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.49992398695339707
#
# 结果对于标签列 Class_E16:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     71366
#            1       0.02      0.08      0.03       999
#
#     accuracy                           0.92     72365
#    macro avg       0.50      0.51      0.49     72365
# weighted avg       0.97      0.92      0.94     72365
#
#  AUC-ROC: 0.5051424697684821
#
# 结果对于标签列 Class_E20:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72311
#            1       0.00      0.00      0.00        54
#
#     accuracy                           0.99     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      0.99      1.00     72365
#
#  AUC-ROC: 0.49760064167277457
#
# 结果对于标签列 Class_F01:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.99      0.96      0.98     71886
#            1       0.01      0.05      0.02       479
#
#     accuracy                           0.96     72365
#    macro avg       0.50      0.51      0.50     72365
# weighted avg       0.99      0.96      0.97     72365
#
#  AUC-ROC: 0.5062232465379393
#
# 结果对于标签列 Class_F02:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     72128
#            1       0.00      0.02      0.00       237
#
#     accuracy                           0.98     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       0.99      0.98      0.98     72365
#
#  AUC-ROC: 0.4981376872433068
#
# 结果对于标签列 Class_F03:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.99      0.92      0.95     71257
#            1       0.02      0.10      0.03      1108
#
#     accuracy                           0.91     72365
#    macro avg       0.50      0.51      0.49     72365
# weighted avg       0.97      0.91      0.94     72365
#
#  AUC-ROC: 0.5116567558452297
#
# 结果对于标签列 Class_F04:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72361
#            1       0.00      0.00      0.00         4
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.4998963530078357
#
# 结果对于标签列 Class_F05:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.97      0.88      0.93     70471
#            1       0.03      0.13      0.05      1894
#
#     accuracy                           0.86     72365
#    macro avg       0.50      0.50      0.49     72365
# weighted avg       0.95      0.86      0.90     72365
#
#  AUC-ROC: 0.5038042377314075
#
# 结果对于标签列 Class_F06:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98     72001
#            1       0.00      0.02      0.01       364
#
#     accuracy                           0.97     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       0.99      0.97      0.98     72365
#
#  AUC-ROC: 0.49755864196635846
#
# 结果对于标签列 Class_F07:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72290
#            1       0.00      0.00      0.00        75
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.4982362705768433
#
# 结果对于标签列 Class_F09:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     72265
#            1       0.00      0.00      0.00       100
#
#     accuracy                           0.99     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      0.99      0.99     72365
#
#  AUC-ROC: 0.49598007334117483
#
# 结果对于标签列 Class_F10:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.96      0.85      0.90     69642
#            1       0.04      0.16      0.06      2723
#
#     accuracy                           0.83     72365
#    macro avg       0.50      0.50      0.48     72365
# weighted avg       0.93      0.83      0.87     72365
#
#  AUC-ROC: 0.504537481196921
#
# 结果对于标签列 Class_F11:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     72308
#            1       0.00      0.02      0.00        57
#
#     accuracy                           0.99     72365
#    macro avg       0.50      0.51      0.50     72365
# weighted avg       1.00      0.99      1.00     72365
#
#  AUC-ROC: 0.5062410895302648
#
# 结果对于标签列 Class_F12:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     72297
#            1       0.00      0.00      0.00        68
#
#     accuracy                           0.99     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      0.99      1.00     72365
#
#  AUC-ROC: 0.4968670899207436
#
# 结果对于标签列 Class_F13:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72311
#            1       0.00      0.00      0.00        54
#
#     accuracy                           0.99     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      0.99      1.00     72365
#
#  AUC-ROC: 0.4975937270954627
#
# 结果对于标签列 Class_F14:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72352
#            1       0.00      0.00      0.00        13
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.49968210968597965
#
# 结果对于标签列 Class_F15:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72348
#            1       0.00      0.00      0.00        17
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.4992190523580472
#
# 结果对于标签列 Class_F16:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72359
#            1       0.00      0.00      0.00         6
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.4997996102765378
#
# 结果对于标签列 Class_F17:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.87      0.71      0.78     63313
#            1       0.12      0.29      0.17      9052
#
#     accuracy                           0.66     72365
#    macro avg       0.50      0.50      0.48     72365
# weighted avg       0.78      0.66      0.71     72365
#
#  AUC-ROC: 0.49936988020413753
#
# 结果对于标签列 Class_G00:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72317
#            1       0.00      0.00      0.00        48
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.49809173500006915
#
# 结果对于标签列 Class_G01:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72351
#            1       0.00      0.00      0.00        14
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.4995577117109646
#
# 结果对于标签列 Class_G02:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72349
#            1       0.00      0.00      0.00        16
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.49938492584555416
#
# 结果对于标签列 Class_G03:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.99      0.96      0.98     71867
#            1       0.01      0.05      0.01       498
#
#     accuracy                           0.95     72365
#    macro avg       0.50      0.50      0.49     72365
# weighted avg       0.99      0.95      0.97     72365
#
#  AUC-ROC: 0.5031040577353872
#
# 结果对于标签列 Class_G04:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     72204
#            1       0.00      0.01      0.00       161
#
#     accuracy                           0.98     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      0.98      0.99     72365
#
#  AUC-ROC: 0.4953982608282743
#
# 结果对于标签列 Class_G05:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72331
#            1       0.00      0.00      0.00        34
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.4984723009498002
#
# 结果对于标签列 Class_G06:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     72296
#            1       0.00      0.00      0.00        69
#
#     accuracy                           0.99     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      0.99      1.00     72365
#
#  AUC-ROC: 0.4967218103352883
#
# 结果对于标签列 Class_G07:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72364
#            1       0.00      0.00      0.00         1
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.49998618097396497
#
# 结果对于标签列 Class_G08:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72332
#            1       0.00      0.00      0.00        33
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.4991566664823315
#
# 结果对于标签列 Class_G09:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72341
#            1       0.00      0.00      0.00        24
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.49915677140210946
#
# 结果对于标签列 Class_G10:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72350
#            1       0.00      0.00      0.00        15
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.49961299239806495
#
# 结果对于标签列 Class_G11:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     72276
#            1       0.00      0.01      0.00        89
#
#     accuracy                           0.99     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      0.99      0.99     72365
#
#  AUC-ROC: 0.5024080599897646
#
# 结果对于标签列 Class_G12:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     72193
#            1       0.00      0.02      0.00       172
#
#     accuracy                           0.98     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      0.98      0.99     72365
#
#  AUC-ROC: 0.5014972381848527
#
# 结果对于标签列 Class_G13:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72359
#            1       0.00      0.00      0.00         6
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.4998134302574662
#
# 结果对于标签列 Class_G14:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72346
#            1       0.00      0.00      0.00        19
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.49937798910789816
#
# 结果对于标签列 Class_G20:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     71445
#            1       0.01      0.07      0.02       920
#
#     accuracy                           0.92     72365
#    macro avg       0.50      0.50      0.49     72365
# weighted avg       0.97      0.92      0.95     72365
#
#  AUC-ROC: 0.5011411560123781
#
# 结果对于标签列 Class_I00:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98     72027
#            1       0.00      0.01      0.00       338
#
#     accuracy                           0.97     72365
#    macro avg       0.50      0.49      0.49     72365
# weighted avg       0.99      0.97      0.98     72365
#
#  AUC-ROC: 0.49077632623466394
#
# 结果对于标签列 Class_I01:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72357
#            1       0.00      0.00      0.00         8
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.49973050292300675
#
# 结果对于标签列 Class_I02:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72361
#            1       0.00      0.00      0.00         4
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.4998065256146267
#
# 结果对于标签列 Class_I05:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     72194
#            1       0.00      0.02      0.01       171
#
#     accuracy                           0.98     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      0.98      0.99     72365
#
#  AUC-ROC: 0.5028793842840935
#
# 结果对于标签列 Class_I06:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72339
#            1       0.00      0.00      0.00        26
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.4993226337107231
#
# 结果对于标签列 Class_I07:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98     71917
#            1       0.00      0.02      0.01       448
#
#     accuracy                           0.96     72365
#    macro avg       0.50      0.50      0.49     72365
# weighted avg       0.99      0.96      0.97     72365
#
#  AUC-ROC: 0.4956047888289874
#
# 结果对于标签列 Class_I08:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.97      0.88      0.93     70482
#            1       0.03      0.13      0.05      1883
#
#     accuracy                           0.86     72365
#    macro avg       0.50      0.51      0.49     72365
# weighted avg       0.95      0.86      0.90     72365
#
#  AUC-ROC: 0.5062403099706304
#
# 结果对于标签列 Class_I09:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72348
#            1       0.00      0.00      0.00        17
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.4989426107148781
#
# 结果对于标签列 Class_I11:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     72152
#            1       0.00      0.02      0.01       213
#
#     accuracy                           0.98     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       0.99      0.98      0.99     72365
#
#  AUC-ROC: 0.5025966634340544
#
# 结果对于标签列 Class_I12:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98     71931
#            1       0.01      0.04      0.01       434
#
#     accuracy                           0.96     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       0.99      0.96      0.97     72365
#
#  AUC-ROC: 0.5031597901650116
#
# 结果对于标签列 Class_I13:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     72332
#            1       0.00      0.00      0.00        33
#
#     accuracy                           1.00     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       1.00      1.00      1.00     72365
#
#  AUC-ROC: 0.4987211745838633
#
# 结果对于标签列 Class_I20:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.90      0.74      0.81     64708
#            1       0.12      0.30      0.17      7657
#
#     accuracy                           0.69     72365
#    macro avg       0.51      0.52      0.49     72365
# weighted avg       0.82      0.69      0.74     72365
#
#  AUC-ROC: 0.5170101264588103
#
# 结果对于标签列 Class_I21:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.93      0.79      0.86     67286
#            1       0.08      0.26      0.13      5079
#
#     accuracy                           0.75     72365
#    macro avg       0.51      0.52      0.49     72365
# weighted avg       0.87      0.75      0.81     72365
#
#  AUC-ROC: 0.5236249512554066
#
# 结果对于标签列 Class_I22:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     72156
#            1       0.01      0.03      0.01       209
#
#     accuracy                           0.98     72365
#    macro avg       0.50      0.51      0.50     72365
# weighted avg       0.99      0.98      0.99     72365
#
#  AUC-ROC: 0.5075147189064841
#
# 结果对于标签列 Class_I50:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.95      0.81      0.88     68097
#            1       0.09      0.30      0.14      4268
#
#     accuracy                           0.78     72365
#    macro avg       0.52      0.56      0.51     72365
# weighted avg       0.90      0.78      0.83     72365
#
#  AUC-ROC: 0.5584884658370683
#
# 结果对于标签列 Class_I25:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.84      0.69      0.76     60462
#            1       0.18      0.35      0.24     11903
#
#     accuracy                           0.63     72365
#    macro avg       0.51      0.52      0.50     72365
# weighted avg       0.73      0.63      0.67     72365
#
#  AUC-ROC: 0.5175837543257782
#
# 结果对于标签列 Class_I48:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.88      0.72      0.79     63450
#            1       0.14      0.32      0.20      8915
#
#     accuracy                           0.67     72365
#    macro avg       0.51      0.52      0.50     72365
# weighted avg       0.79      0.67      0.72     72365
#
#  AUC-ROC: 0.5233903025111961
#
# 结果对于标签列 Class_I63:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.95      0.82      0.88     68741
#            1       0.05      0.19      0.08      3624
#
#     accuracy                           0.79     72365
#    macro avg       0.50      0.51      0.48     72365
# weighted avg       0.91      0.79      0.84     72365
#
#  AUC-ROC: 0.5050768636844709
#
# 结果对于标签列 Class_I10:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.47      0.50      0.48     31784
#            1       0.58      0.55      0.57     40581
#
#     accuracy                           0.53     72365
#    macro avg       0.53      0.53      0.52     72365
# weighted avg       0.53      0.53      0.53     72365
#
#  AUC-ROC: 0.5256513976084337
#
# 结果对于标签列 Class_F00:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.99      0.94      0.96     71412
#            1       0.02      0.10      0.03       953
#
#     accuracy                           0.93     72365
#    macro avg       0.50      0.52      0.50     72365
# weighted avg       0.97      0.93      0.95     72365
#
#  AUC-ROC: 0.5188954225627984
#
# 结果对于标签列 Class_F20:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     72130
#            1       0.00      0.02      0.01       235
#
#     accuracy                           0.98     72365
#    macro avg       0.50      0.50      0.50     72365
# weighted avg       0.99      0.98      0.98     72365
#
#  AUC-ROC: 0.5004622268893929
#
# 结果对于标签列 Class_C50:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.95      0.82      0.88     68527
#            1       0.06      0.22      0.10      3838
#
#     accuracy                           0.79     72365
#    macro avg       0.51      0.52      0.49     72365
# weighted avg       0.90      0.79      0.84     72365
#
#  AUC-ROC: 0.5197896725233073
#
# 结果对于标签列 Class_C18:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.97      0.87      0.92     70333
#            1       0.03      0.14      0.05      2032
#
#     accuracy                           0.85     72365
#    macro avg       0.50      0.51      0.49     72365
# weighted avg       0.95      0.85      0.90     72365
#
#  AUC-ROC: 0.5064064366297516
#
# 结果对于标签列 Class_C56:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98     71950
#            1       0.00      0.03      0.01       415
#
#     accuracy                           0.96     72365
#    macro avg       0.50      0.50      0.49     72365
# weighted avg       0.99      0.96      0.97     72365
#
#  AUC-ROC: 0.49657476326431504
#
# 结果对于标签列 Class_J45:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.80      0.66      0.72     57317
#            1       0.22      0.37      0.28     15048
#
#     accuracy                           0.60     72365
#    macro avg       0.51      0.51      0.50     72365
# weighted avg       0.68      0.60      0.63     72365
#
#  AUC-ROC: 0.5149592829137362
#
# 结果对于标签列 Class_M05:
#  分类报告:
#                precision    recall  f1-score   support
#
#            0       0.96      0.85      0.91     69712
#            1       0.04      0.15      0.06      2653
#
#     accuracy                           0.83     72365
#    macro avg       0.50      0.50      0.48     72365
# weighted avg       0.93      0.83      0.87     72365
#
#  AUC-ROC: 0.5009089575236733
